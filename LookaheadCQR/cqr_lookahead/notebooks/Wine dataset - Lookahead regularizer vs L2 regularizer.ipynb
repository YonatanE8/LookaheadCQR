# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV

from LookaheadCQR.cqr_lookahead.uncertainty import CQR
from LookaheadCQR.lookahead.models.lookahead import Lookahead
import LookaheadCQR.lookahead.models.uncertainty as uncert
import LookaheadCQR.lookahead.models.prediction as pred
import LookaheadCQR.lookahead.models.propensity as prop

# %matplotlib inline
np.set_printoptions(precision=3)

# %% [markdown]
# ## Loading the wine data

# %%
#load data
x,y0 = data = load_wine(return_X_y=True)
scaler = StandardScaler()
scaler.fit(x)
scaler.transform(x, copy=False)
n = x.shape[0]
d = x.shape[1]

# %% [markdown]
# ## Defining the groundtruth model.
# Here we choose Ridge Regression with polynomial features (degree =2) as the groundtruth function f* and
# select the best model using 5 - fold cross validation.

# %%
class Fstar():
    def __init__(self):
        self.model = RidgeCV(alphas=alpha_range)
    def fit(self, x, y):
        x2 = np.hstack([x, 0.5*x**2]).round(3)
        self.model.fit(x2, y)
    def predict(self, x):
        x2 = np.hstack([x, 0.5*x**2]).round(3)
        return self.model.predict(x2)

# %%
# Hyperparamters for the ground truth model
C_range = 2. ** np.arange(-8,10,2)
gamma_range = 2. ** np.arange(-10,3,2)
alpha_range = 2.**np.arange(-8,8)
param_grid = {'gamma':gamma_range, 'C':C_range}

# Train the model
fstar = Fstar()
fstar.fit(x, y0)
y = fstar.predict(x)
mse_star = np.mean(np.square(y-y0))
mae_star = np.mean(np.abs(y-y0))
print("[f*] mse(y,y0):", mse_star)
print("[f*] mae(y,y0):", mae_star)
# Out:
# [f*] mse(y,y0): 0.04106275149850199
# [f*] mae(y,y0): 0.1626729186916224

# %% [markdown]
# ## Visualizing the features.
# Features 0,1 have non-linaer relation to y

# %%
plt.rcParams['figure.figsize'] = (12.0, 4.0)

plt.subplot(121)
plt.scatter(x[:,0], y, s=10)
plt.xlabel('x0')
plt.ylabel('y')

plt.subplot(122)
plt.scatter(x[:,1], y, s=10)
plt.xlabel('x1')
plt.ylabel('y')
plt.show()


# np.corrcoef(x_trn[:,i],y_trn[:])[0,1]

# %% [markdown]
# ## Generating the train-test splits

# %%
# split data
trn_sz = 0.75
seed = 1

active = np.where(np.logical_and(x[:,0]>=-0.2,x[:,1]<=-0.3))[0]

x_active = x[active,:]
y_active = y0[active]
n_active = y_active.shape[0]

x_trn, x_tst, y_trn, y_tst = train_test_split(x_active, y_active, test_size=1-trn_sz, random_state=seed)
n_trn, n_tst = (x_trn.shape[0], x_tst.shape[0])
print('n:', n, ', n_active:', n_active, ", n_trn:", n_trn, ", n_tst:", n_tst)

xs = [x_trn, x_tst, x_active, x]
ys = [y_trn, y_tst, y_active, y]
# Out:
# n: 178 , n_active: 57 , n_trn: 42 , n_tst: 15

# %% [markdown]
# ## Setting the hyperparamters of the look ahead model

# %%
# Step Size
eta = 2.

# L2 regularization coefficients
alphas = np.hstack([1e-5, 2.**np.arange(-8,6,1)])

# Lookahead regularization coefficient
lams = np.hstack([1e-5, 2.**np.arange(-4,2,1)]) #lookahead penalty coefficients

# Setting features that can by altered using mask
# Features - 0, 1, 4, 5, 7 and 8 are the only non-immutable features
mask = np.zeros(d)
mask[[0,1,4,5,7,8]] = 1

# Number of cycles to train
num_cycles = 10

# Confidence Intervals
z_score = 1.65 # for confiednce intervals (1.28-90%, 1.65=95%)

""" Hyperparameters for Prediction Model"""
# L2 - regularization coeffs
alpha_f = 0.5
# Regularization type (L1/L2)
reg_type = 'l2'
# Learning rate
lr_f = 0.1
# Number of iterations
num_iter_init = 1000 #for initial f
num_iter_f = 100 #for training f in cycles

""" Hyperparameters for Uncertainty Model"""
# Number of bootstrapped models
num_gs = 20
# Learning rate
lr_g = 0.1
# Number of iterations
num_iter_g = 500 #for training g in cycles

# %% [markdown]
# ## Training a baseline model and displaying the weights learnt and the result

# %%
# baselines
verbose = True

# scikitlearn - to get optimal regularization coefficient via CV)
f_base_skl = RidgeCV(alphas=alphas, cv=None).fit(x_trn, y_trn)
w_base_skl = f_base_skl.coef_
best_alpha = float(f_base_skl.alpha_)
best_alpha_idx = int(np.where(alphas==best_alpha)[0])

# benchmark trained on all data
f_bench = RidgeCV(alphas=alphas, cv=None).fit(x, y)
w_bench = f_bench.coef_

# ours - for sanity check (vs SKL) and to get baseline improvement
f_base = pred.PredModel(d, reg_type=reg_type, alpha=best_alpha, lr=lr_f, num_iter_init=num_iter_init)
model_base = Lookahead(f_base, None, None, lam=0., eta=eta, mask=mask, ground_truth_model=fstar)
_, _ = model_base.train(x_trn, y_trn, num_cycles=0, random_state=seed, verbose=verbose)

plt.rcParams['figure.figsize'] = (14.0, 3.0)
barWidth = 0.35
plt.bar(np.arange(d)-barWidth/2,w_base_skl/np.sum(np.abs(w_base_skl)),alpha=0.6,width=barWidth)
plt.bar(np.arange(d)+barWidth/2,w_bench/np.sum(np.abs(w_bench)),alpha=0.6,width=barWidth)
plt.xticks(np.arange(d))
plt.title('model parameters')
plt.ylabel('value')
plt.xlabel('feature number')
plt.legend(['train data','all data'])
plt.grid()
plt.show()

perf_base_skl = {'mse':[], 'mae':[]}
for x_,y_ in zip(xs, ys):
    yhat_ = f_base_skl.predict(x_)
    perf_base_skl['mse'].append(np.mean(np.square(y_-yhat_)))
    perf_base_skl['mae'].append(np.mean(np.abs(y_-yhat_)))
print('baseline: (skl)')
print('\t\ttrn\ttst\tactv\tall')
print(('mse'+'\t{:.4f}'*4).format(*perf_base_skl['mse']))
print(('mae'+'\t{:.4f}'*4).format(*perf_base_skl['mae']))
print()

perf_base = {'mse':[], 'mae':[], 'improve':[]}
for x_,y_ in zip(xs, ys):
    perf_base['mse'].append(model_base.mse(x_,y_))
    perf_base['mae'].append(model_base.mae(x_,y_))
    perf_base['improve'].append(model_base.improve(x_,y_,eta,mask))
print('baseline: (ours)')
print('base:\ttrn\ttst\tactv\tall')
print(('mse'+'\t{:.4f}'*4).format(*perf_base['mse']))
print(('mae'+'\t{:.4f}'*4).format(*perf_base['mae']))
print(('imprv'+'\t{:.4f}'*4).format(*perf_base['improve']))
print()

print('best reg coef:', best_alpha, ', idx:', best_alpha_idx)
# Out:
# t: 0
# [f] mse: 0.0557, la_reg: 0.0000, norm_reg: 0.0034, obj: 0.0832
# [f] improve*: 0.036
#
# baseline: (skl)
# 		trn	tst	actv	all
# mse	0.0557	0.0511	0.0544	0.0780
# mae	0.1932	0.1750	0.1884	0.2229
#
# baseline: (ours)
# base:	trn	tst	actv	all
# mse	0.0557	0.0511	0.0544	0.0780
# mae	0.1932	0.1750	0.1884	0.2229
# imprv	0.0358	-0.0323	0.0179	-0.0039
#
# best reg coef: 8.0 , idx: 12

# %% [markdown]
# ## Training the lookahead model for different values of lam

# %%
# train our model
verbose = True

models = []
mfs = []
mus = []
for lam_ in lams:
    print('-- lam_:', lam_, '--')
    f = pred.PredModel(d, reg_type=reg_type, alpha=alpha_f, lr=lr_f, num_iter=num_iter_f, num_iter_init=num_iter_init)
    u = uncert.BootstrapResid(d, f, alpha=0., num_gs=num_gs, z_score=z_score, lr=lr_g, num_iter=num_iter_g)
    h = prop.PropModel(random_state=seed)

    model = Lookahead(f, u, h, lam=lam_, eta=eta, mask=mask, ground_truth_model=fstar)
    mf, mu = model.train(x_trn, y_trn, num_cycles=num_cycles, random_state=seed, verbose=verbose)

    models.append(model)
    mfs.append(mf)
    mus.append(mu)

mus = np.asarray(mus)
mfs = np.asarray(mfs)
# Out:
# -- lam_: 1e-05 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1652, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 2
# [h] n_eff: 34.91, w_sum: 37.75
# [u] loss: 0.0765, norm_reg: 0.0000, obj: 0.0765
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1655, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 3
# [h] n_eff: 34.92, w_sum: 37.84
# [u] loss: 0.0764, norm_reg: 0.0000, obj: 0.0764
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1656, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 4
# [h] n_eff: 34.93, w_sum: 37.90
# [u] loss: 0.0764, norm_reg: 0.0000, obj: 0.0764
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1658, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 5
# [h] n_eff: 34.93, w_sum: 37.94
# [u] loss: 0.0764, norm_reg: 0.0000, obj: 0.0764
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1658, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 6
# [h] n_eff: 34.93, w_sum: 37.96
# [u] loss: 0.0763, norm_reg: 0.0000, obj: 0.0763
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1659, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 7
# [h] n_eff: 34.93, w_sum: 37.98
# [u] loss: 0.0763, norm_reg: 0.0000, obj: 0.0763
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1659, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 8
# [h] n_eff: 34.93, w_sum: 37.99
# [u] loss: 0.0763, norm_reg: 0.0000, obj: 0.0763
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1660, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 9
# [h] n_eff: 34.93, w_sum: 38.00
# [u] loss: 0.0763, norm_reg: 0.0000, obj: 0.0763
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1660, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 10
# [h] n_eff: 34.93, w_sum: 38.01
# [u] loss: 0.0763, norm_reg: 0.0000, obj: 0.0763
# [u] size: 0.409, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1660, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# -- lam_: 0.0625 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0438, la_reg: 0.1545, norm_reg: 0.0091, obj: 0.0580
# [f] improve*: 0.055
#
# t: 2
# [h] n_eff: 31.12, w_sum: 32.24
# [u] loss: 0.0760, norm_reg: 0.0000, obj: 0.0760
# [u] size: 0.429, contain*: 0.643
# [f] mse: 0.0438, la_reg: 0.1620, norm_reg: 0.0093, obj: 0.0585
# [f] improve*: 0.055
#
# t: 3
# [h] n_eff: 30.22, w_sum: 29.77
# [u] loss: 0.0755, norm_reg: 0.0000, obj: 0.0755
# [u] size: 0.434, contain*: 0.643
# [f] mse: 0.0438, la_reg: 0.1587, norm_reg: 0.0094, obj: 0.0584
# [f] improve*: 0.055
#
# t: 4
# [h] n_eff: 29.45, w_sum: 27.47
# [u] loss: 0.0750, norm_reg: 0.0000, obj: 0.0750
# [u] size: 0.438, contain*: 0.643
# [f] mse: 0.0438, la_reg: 0.1565, norm_reg: 0.0095, obj: 0.0584
# [f] improve*: 0.055
#
# t: 5
# [h] n_eff: 28.88, w_sum: 25.88
# [u] loss: 0.0746, norm_reg: 0.0000, obj: 0.0746
# [u] size: 0.442, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1549, norm_reg: 0.0096, obj: 0.0583
# [f] improve*: 0.056
#
# t: 6
# [h] n_eff: 28.48, w_sum: 24.76
# [u] loss: 0.0742, norm_reg: 0.0000, obj: 0.0742
# [u] size: 0.444, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1541, norm_reg: 0.0096, obj: 0.0583
# [f] improve*: 0.055
#
# t: 7
# [h] n_eff: 28.28, w_sum: 24.21
# [u] loss: 0.0741, norm_reg: 0.0000, obj: 0.0741
# [u] size: 0.445, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1534, norm_reg: 0.0096, obj: 0.0583
# [f] improve*: 0.056
#
# t: 8
# [h] n_eff: 28.15, w_sum: 23.81
# [u] loss: 0.0740, norm_reg: 0.0000, obj: 0.0740
# [u] size: 0.446, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1530, norm_reg: 0.0097, obj: 0.0583
# [f] improve*: 0.056
#
# t: 9
# [h] n_eff: 28.03, w_sum: 23.50
# [u] loss: 0.0739, norm_reg: 0.0000, obj: 0.0739
# [u] size: 0.447, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1526, norm_reg: 0.0097, obj: 0.0583
# [f] improve*: 0.056
#
# t: 10
# [h] n_eff: 27.92, w_sum: 23.23
# [u] loss: 0.0738, norm_reg: 0.0000, obj: 0.0738
# [u] size: 0.448, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1524, norm_reg: 0.0097, obj: 0.0583
# [f] improve*: 0.056
#
# -- lam_: 0.125 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0439, la_reg: 0.1473, norm_reg: 0.0096, obj: 0.0671
# [f] improve*: 0.059
#
# t: 2
# [h] n_eff: 29.04, w_sum: 26.94
# [u] loss: 0.0748, norm_reg: 0.0000, obj: 0.0748
# [u] size: 0.442, contain*: 0.643
# [f] mse: 0.0439, la_reg: 0.1571, norm_reg: 0.0101, obj: 0.0686
# [f] improve*: 0.058
#
# t: 3
# [h] n_eff: 27.70, w_sum: 23.29
# [u] loss: 0.0738, norm_reg: 0.0000, obj: 0.0738
# [u] size: 0.452, contain*: 0.667
# [f] mse: 0.0440, la_reg: 0.1491, norm_reg: 0.0104, obj: 0.0679
# [f] improve*: 0.059
#
# t: 4
# [h] n_eff: 26.78, w_sum: 19.46
# [u] loss: 0.0730, norm_reg: 0.0000, obj: 0.0730
# [u] size: 0.460, contain*: 0.690
# [f] mse: 0.0441, la_reg: 0.1452, norm_reg: 0.0106, obj: 0.0676
# [f] improve*: 0.059
#
# t: 5
# [h] n_eff: 26.29, w_sum: 17.68
# [u] loss: 0.0726, norm_reg: 0.0000, obj: 0.0726
# [u] size: 0.465, contain*: 0.667
# [f] mse: 0.0442, la_reg: 0.1422, norm_reg: 0.0108, obj: 0.0674
# [f] improve*: 0.059
#
# t: 6
# [h] n_eff: 25.99, w_sum: 16.38
# [u] loss: 0.0723, norm_reg: 0.0000, obj: 0.0723
# [u] size: 0.470, contain*: 0.690
# [f] mse: 0.0443, la_reg: 0.1407, norm_reg: 0.0110, obj: 0.0674
# [f] improve*: 0.060
#
# t: 7
# [h] n_eff: 25.80, w_sum: 15.64
# [u] loss: 0.0721, norm_reg: 0.0000, obj: 0.0721
# [u] size: 0.473, contain*: 0.690
# [f] mse: 0.0444, la_reg: 0.1398, norm_reg: 0.0110, obj: 0.0673
# [f] improve*: 0.060
#
# t: 8
# [h] n_eff: 25.70, w_sum: 15.20
# [u] loss: 0.0720, norm_reg: 0.0000, obj: 0.0720
# [u] size: 0.475, contain*: 0.714
# [f] mse: 0.0444, la_reg: 0.1392, norm_reg: 0.0111, obj: 0.0673
# [f] improve*: 0.060
#
# t: 9
# [h] n_eff: 25.64, w_sum: 14.93
# [u] loss: 0.0719, norm_reg: 0.0000, obj: 0.0719
# [u] size: 0.476, contain*: 0.714
# [f] mse: 0.0444, la_reg: 0.1389, norm_reg: 0.0111, obj: 0.0673
# [f] improve*: 0.060
#
# t: 10
# [h] n_eff: 25.61, w_sum: 14.78
# [u] loss: 0.0719, norm_reg: 0.0000, obj: 0.0719
# [u] size: 0.477, contain*: 0.714
# [f] mse: 0.0444, la_reg: 0.1387, norm_reg: 0.0112, obj: 0.0673
# [f] improve*: 0.060
#
# -- lam_: 0.25 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0443, la_reg: 0.1371, norm_reg: 0.0108, obj: 0.0840
# [f] improve*: 0.066
#
# t: 2
# [h] n_eff: 26.55, w_sum: 19.37
# [u] loss: 0.0731, norm_reg: 0.0000, obj: 0.0731
# [u] size: 0.467, contain*: 0.667
# [f] mse: 0.0445, la_reg: 0.1500, norm_reg: 0.0119, obj: 0.0880
# [f] improve*: 0.063
#
# t: 3
# [h] n_eff: 25.44, w_sum: 16.47
# [u] loss: 0.0721, norm_reg: 0.0000, obj: 0.0721
# [u] size: 0.482, contain*: 0.690
# [f] mse: 0.0452, la_reg: 0.1290, norm_reg: 0.0129, obj: 0.0839
# [f] improve*: 0.067
#
# t: 4
# [h] n_eff: 25.37, w_sum: 10.35
# [u] loss: 0.0721, norm_reg: 0.0000, obj: 0.0721
# [u] size: 0.505, contain*: 0.714
# [f] mse: 0.0457, la_reg: 0.1235, norm_reg: 0.0137, obj: 0.0834
# [f] improve*: 0.068
#
# t: 5
# [h] n_eff: 24.95, w_sum: 9.31
# [u] loss: 0.0717, norm_reg: 0.0000, obj: 0.0717
# [u] size: 0.519, contain*: 0.738
# [f] mse: 0.0460, la_reg: 0.1187, norm_reg: 0.0142, obj: 0.0827
# [f] improve*: 0.069
#
# t: 6
# [h] n_eff: 25.10, w_sum: 8.22
# [u] loss: 0.0718, norm_reg: 0.0000, obj: 0.0718
# [u] size: 0.529, contain*: 0.738
# [f] mse: 0.0461, la_reg: 0.1180, norm_reg: 0.0144, obj: 0.0829
# [f] improve*: 0.070
#
# t: 7
# [h] n_eff: 25.04, w_sum: 7.93
# [u] loss: 0.0718, norm_reg: 0.0000, obj: 0.0718
# [u] size: 0.534, contain*: 0.762
# [f] mse: 0.0462, la_reg: 0.1175, norm_reg: 0.0146, obj: 0.0829
# [f] improve*: 0.071
#
# t: 8
# [h] n_eff: 25.06, w_sum: 7.75
# [u] loss: 0.0718, norm_reg: 0.0000, obj: 0.0718
# [u] size: 0.537, contain*: 0.762
# [f] mse: 0.0463, la_reg: 0.1174, norm_reg: 0.0146, obj: 0.0829
# [f] improve*: 0.071
#
# t: 9
# [h] n_eff: 25.04, w_sum: 7.69
# [u] loss: 0.0717, norm_reg: 0.0000, obj: 0.0717
# [u] size: 0.538, contain*: 0.762
# [f] mse: 0.0463, la_reg: 0.1174, norm_reg: 0.0147, obj: 0.0829
# [f] improve*: 0.071
#
# t: 10
# [h] n_eff: 25.04, w_sum: 7.66
# [u] loss: 0.0717, norm_reg: 0.0000, obj: 0.0717
# [u] size: 0.538, contain*: 0.762
# [f] mse: 0.0463, la_reg: 0.1174, norm_reg: 0.0147, obj: 0.0830
# [f] improve*: 0.071
#
# -- lam_: 0.5 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0460, la_reg: 0.1238, norm_reg: 0.0134, obj: 0.1146
# [f] improve*: 0.078
#
# t: 2
# [h] n_eff: 25.27, w_sum: 11.93
# [u] loss: 0.0723, norm_reg: 0.0000, obj: 0.0723
# [u] size: 0.514, contain*: 0.714
# [f] mse: 0.0473, la_reg: 0.1380, norm_reg: 0.0158, obj: 0.1243
# [f] improve*: 0.074
#
# t: 3
# [h] n_eff: 23.75, w_sum: 10.29
# [u] loss: 0.0716, norm_reg: 0.0000, obj: 0.0716
# [u] size: 0.545, contain*: 0.690
# [f] mse: 0.0496, la_reg: 0.0971, norm_reg: 0.0189, obj: 0.1076
# [f] improve*: 0.085
#
# t: 4
# [h] n_eff: 26.42, w_sum: 4.64
# [u] loss: 0.0744, norm_reg: 0.0000, obj: 0.0744
# [u] size: 0.614, contain*: 0.738
# [f] mse: 0.0505, la_reg: 0.0980, norm_reg: 0.0201, obj: 0.1095
# [f] improve*: 0.085
#
# t: 5
# [h] n_eff: 25.34, w_sum: 4.54
# [u] loss: 0.0733, norm_reg: 0.0000, obj: 0.0733
# [u] size: 0.642, contain*: 0.667
# [f] mse: 0.0504, la_reg: 0.0984, norm_reg: 0.0201, obj: 0.1096
# [f] improve*: 0.086
#
# t: 6
# [h] n_eff: 25.84, w_sum: 4.28
# [u] loss: 0.0737, norm_reg: 0.0000, obj: 0.0737
# [u] size: 0.645, contain*: 0.714
# [f] mse: 0.0505, la_reg: 0.0996, norm_reg: 0.0201, obj: 0.1103
# [f] improve*: 0.086
#
# t: 7
# [h] n_eff: 25.56, w_sum: 4.37
# [u] loss: 0.0734, norm_reg: 0.0000, obj: 0.0734
# [u] size: 0.647, contain*: 0.714
# [f] mse: 0.0505, la_reg: 0.0997, norm_reg: 0.0203, obj: 0.1105
# [f] improve*: 0.087
#
# t: 8
# [h] n_eff: 25.62, w_sum: 4.33
# [u] loss: 0.0735, norm_reg: 0.0000, obj: 0.0735
# [u] size: 0.649, contain*: 0.714
# [f] mse: 0.0506, la_reg: 0.0998, norm_reg: 0.0204, obj: 0.1107
# [f] improve*: 0.088
#
# t: 9
# [h] n_eff: 25.57, w_sum: 4.33
# [u] loss: 0.0735, norm_reg: 0.0000, obj: 0.0735
# [u] size: 0.652, contain*: 0.714
# [f] mse: 0.0506, la_reg: 0.1003, norm_reg: 0.0204, obj: 0.1109
# [f] improve*: 0.088
#
# t: 10
# [h] n_eff: 25.56, w_sum: 4.34
# [u] loss: 0.0735, norm_reg: 0.0000, obj: 0.0735
# [u] size: 0.652, contain*: 0.714
# [f] mse: 0.0506, la_reg: 0.1005, norm_reg: 0.0204, obj: 0.1110
# [f] improve*: 0.088
#
# -- lam_: 1.0 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0510, la_reg: 0.1088, norm_reg: 0.0183, obj: 0.1689
# [f] improve*: 0.096
#
# t: 2
# [h] n_eff: 25.57, w_sum: 6.89
# [u] loss: 0.0743, norm_reg: 0.0000, obj: 0.0743
# [u] size: 0.602, contain*: 0.762
# [f] mse: 0.0573, la_reg: 0.1201, norm_reg: 0.0237, obj: 0.1893
# [f] improve*: 0.091
#
# t: 3
# [h] n_eff: 23.12, w_sum: 5.61
# [u] loss: 0.0755, norm_reg: 0.0000, obj: 0.0755
# [u] size: 0.695, contain*: 0.595
# [f] mse: 0.0609, la_reg: 0.0646, norm_reg: 0.0308, obj: 0.1409
# [f] improve*: 0.113
#
# t: 4
# [h] n_eff: 28.31, w_sum: 2.20
# [u] loss: 0.0809, norm_reg: 0.0000, obj: 0.0809
# [u] size: 0.882, contain*: 0.738
# [f] mse: 0.0627, la_reg: 0.0822, norm_reg: 0.0318, obj: 0.1609
# [f] improve*: 0.114
#
# t: 5
# [h] n_eff: 25.46, w_sum: 2.45
# [u] loss: 0.0783, norm_reg: 0.0000, obj: 0.0783
# [u] size: 0.946, contain*: 0.643
# [f] mse: 0.0607, la_reg: 0.0976, norm_reg: 0.0300, obj: 0.1733
# [f] improve*: 0.117
#
# t: 6
# [h] n_eff: 25.80, w_sum: 2.64
# [u] loss: 0.0779, norm_reg: 0.0000, obj: 0.0779
# [u] size: 0.887, contain*: 0.667
# [f] mse: 0.0603, la_reg: 0.0957, norm_reg: 0.0293, obj: 0.1707
# [f] improve*: 0.115
#
# t: 7
# [h] n_eff: 24.96, w_sum: 2.85
# [u] loss: 0.0768, norm_reg: 0.0000, obj: 0.0768
# [u] size: 0.882, contain*: 0.643
# [f] mse: 0.0599, la_reg: 0.0978, norm_reg: 0.0289, obj: 0.1721
# [f] improve*: 0.116
#
# t: 8
# [h] n_eff: 25.25, w_sum: 2.85
# [u] loss: 0.0770, norm_reg: 0.0000, obj: 0.0770
# [u] size: 0.873, contain*: 0.643
# [f] mse: 0.0597, la_reg: 0.0983, norm_reg: 0.0287, obj: 0.1724
# [f] improve*: 0.115
#
# t: 9
# [h] n_eff: 24.88, w_sum: 2.95
# [u] loss: 0.0765, norm_reg: 0.0000, obj: 0.0765
# [u] size: 0.868, contain*: 0.643
# [f] mse: 0.0595, la_reg: 0.0991, norm_reg: 0.0285, obj: 0.1729
# [f] improve*: 0.116
#
# t: 10
# [h] n_eff: 25.00, w_sum: 2.96
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.865, contain*: 0.643
# [f] mse: 0.0595, la_reg: 0.0994, norm_reg: 0.0284, obj: 0.1730
# [f] improve*: 0.116
#
# -- lam_: 2.0 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0766, norm_reg: 0.0000, obj: 0.0766
# [u] size: 0.410, contain*: 0.667
# [f] mse: 0.0636, la_reg: 0.0921, norm_reg: 0.0273, obj: 0.2614
# [f] improve*: 0.121
#
# t: 2
# [h] n_eff: 25.95, w_sum: 3.95
# [u] loss: 0.0799, norm_reg: 0.0000, obj: 0.0799
# [u] size: 0.776, contain*: 0.762
# [f] mse: 0.0861, la_reg: 0.0996, norm_reg: 0.0391, obj: 0.3048
# [f] improve*: 0.119
#
# t: 3
# [h] n_eff: 23.27, w_sum: 2.78
# [u] loss: 0.0898, norm_reg: 0.0000, obj: 0.0898
# [u] size: 1.106, contain*: 0.571
# [f] mse: 0.0853, la_reg: 0.0559, norm_reg: 0.0488, obj: 0.2215
# [f] improve*: 0.143
#
# t: 4
# [h] n_eff: 28.92, w_sum: 1.32
# [u] loss: 0.0948, norm_reg: 0.0000, obj: 0.0948
# [u] size: 1.344, contain*: 0.714
# [f] mse: 0.0928, la_reg: 0.0658, norm_reg: 0.0530, obj: 0.2509
# [f] improve*: 0.155
#
# t: 5
# [h] n_eff: 25.82, w_sum: 1.35
# [u] loss: 0.0947, norm_reg: 0.0000, obj: 0.0947
# [u] size: 1.612, contain*: 0.762
# [f] mse: 0.0883, la_reg: 0.1169, norm_reg: 0.0433, obj: 0.3438
# [f] improve*: 0.158
#
# t: 6
# [h] n_eff: 24.84, w_sum: 2.02
# [u] loss: 0.0930, norm_reg: 0.0000, obj: 0.0930
# [u] size: 1.250, contain*: 0.643
# [f] mse: 0.0894, la_reg: 0.0804, norm_reg: 0.0466, obj: 0.2736
# [f] improve*: 0.152
#
# t: 7
# [h] n_eff: 24.78, w_sum: 1.67
# [u] loss: 0.0934, norm_reg: 0.0000, obj: 0.0934
# [u] size: 1.463, contain*: 0.667
# [f] mse: 0.0897, la_reg: 0.1031, norm_reg: 0.0454, obj: 0.3186
# [f] improve*: 0.163
#
# t: 8
# [h] n_eff: 24.89, w_sum: 1.86
# [u] loss: 0.0935, norm_reg: 0.0000, obj: 0.0935
# [u] size: 1.333, contain*: 0.643
# [f] mse: 0.0924, la_reg: 0.0909, norm_reg: 0.0466, obj: 0.2974
# [f] improve*: 0.160
#
# t: 9
# [h] n_eff: 24.05, w_sum: 1.78
# [u] loss: 0.0940, norm_reg: 0.0000, obj: 0.0940
# [u] size: 1.440, contain*: 0.667
# [f] mse: 0.0922, la_reg: 0.1033, norm_reg: 0.0457, obj: 0.3216
# [f] improve*: 0.168
#
# t: 10
# [h] n_eff: 24.51, w_sum: 1.88
# [u] loss: 0.0947, norm_reg: 0.0000, obj: 0.0947
# [u] size: 1.368, contain*: 0.667
# [f] mse: 0.0925, la_reg: 0.0971, norm_reg: 0.0457, obj: 0.3097
# [f] improve*: 0.163

# %% [markdown]
# # Evaluating the performance of the trained lookahead models

# %%
# evaluate

perf_la = {'mse':[], 'mae':[], 'improve':[], 'contain':[], 'size':[]}
for lam, model in zip(lams,models):
    perf_la['mse'].append([model.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_la['mae'].append([model.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_la['improve'].append([model.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])

    xsp = [model.move_points(x_) for x_ in xs]
    perf_la['contain'].append([model.contain(x_)[0] for x_ in [*xsp, x]])
    perf_la['size'].append([model.contain(x_)[1] for x_ in [*xsp, x]])
perf_la = {k:np.asarray(v) for k,v in zip(perf_la.keys(),perf_la.values())}

print('lookahead: eta:', eta)
for i in range(len(lams)):
    print('\n==============================================\n')
    print('lam:', lams[i])
    print('\ttrn\tts\tactv\tall\tf*')
    print(('mse'+'\t{:.4f}'*5).format(*perf_la['mse'][i,:], mse_star))
    print(('mae'+'\t{:.4f}'*5).format(*perf_la['mae'][i,:], mae_star))
    print(('imprv'+'\t{:.4f}'*4).format(*perf_la['improve'][i,:]))
    print()
    print('\ttrn\'\ttst\'\tactv\'\tall\'\tall')
    print(('contn'+'\t{:.3f}'*5).format(*perf_la['contain'][i,:]))
    print(('intrsz'+'\t{:.3f}'*5).format(*perf_la['size'][i,:]))
# Out:
# lookahead: eta: 2.0
#
# ==============================================
#
# lam: 1e-05
# 	trn	ts	actv	all	f*
# mse	0.0438	0.0580	0.0476	0.1046	0.0411
# mae	0.1696	0.1794	0.1722	0.2532	0.1627
# imprv	0.0507	-0.0148	0.0335	0.0078
#
# 	trn'	tst'	actv'	all'	all
# contn	0.667	0.800	0.702	0.556	0.517
# intrsz	0.409	0.460	0.423	0.696	0.698
#
# ==============================================
#
# lam: 0.0625
# 	trn	ts	actv	all	f*
# mse	0.0439	0.0531	0.0463	0.2150	0.0411
# mae	0.1709	0.1703	0.1707	0.3610	0.1627
# imprv	0.0557	-0.0093	0.0386	0.0110
#
# 	trn'	tst'	actv'	all'	all
# contn	0.690	0.733	0.702	0.528	0.466
# intrsz	0.448	0.511	0.465	0.700	0.720
#
# ==============================================
#
# lam: 0.125
# 	trn	ts	actv	all	f*
# mse	0.0444	0.0504	0.0460	0.3244	0.0411
# mae	0.1717	0.1641	0.1697	0.4367	0.1627
# imprv	0.0603	-0.0043	0.0433	0.0145
#
# 	trn'	tst'	actv'	all'	all
# contn	0.714	0.800	0.737	0.539	0.478
# intrsz	0.477	0.550	0.496	0.709	0.736
#
# ==============================================
#
# lam: 0.25
# 	trn	ts	actv	all	f*
# mse	0.0463	0.0476	0.0466	0.5584	0.0411
# mae	0.1740	0.1641	0.1714	0.5626	0.1627
# imprv	0.0710	0.0076	0.0543	0.0234
#
# 	trn'	tst'	actv'	all'	all
# contn	0.762	0.800	0.772	0.590	0.461
# intrsz	0.538	0.618	0.559	0.727	0.746
#
# ==============================================
#
# lam: 0.5
# 	trn	ts	actv	all	f*
# mse	0.0506	0.0493	0.0503	0.9054	0.0411
# mae	0.1825	0.1667	0.1783	0.7085	0.1627
# imprv	0.0877	0.0258	0.0714	0.0380
#
# 	trn'	tst'	actv'	all'	all
# contn	0.714	0.800	0.737	0.624	0.466
# intrsz	0.652	0.735	0.674	0.794	0.777
#
# ==============================================
#
# lam: 1.0
# 	trn	ts	actv	all	f*
# mse	0.0595	0.0646	0.0608	1.2638	0.0411
# mae	0.1961	0.1946	0.1957	0.8368	0.1627
# imprv	0.1157	0.0560	0.1000	0.0642
#
# 	trn'	tst'	actv'	all'	all
# contn	0.643	0.800	0.684	0.708	0.500
# intrsz	0.862	0.956	0.887	0.969	0.868
#
# ==============================================
#
# lam: 2.0
# 	trn	ts	actv	all	f*
# mse	0.0925	0.1466	0.1068	1.9299	0.0411
# mae	0.2409	0.3132	0.2599	1.0529	0.1627
# imprv	0.1634	0.1069	0.1486	0.1115
#
# 	trn'	tst'	actv'	all'	all
# contn	0.667	0.800	0.702	0.837	0.669
# intrsz	1.360	1.500	1.397	1.454	1.158

# %% [markdown]
# ## Training the lookahead + CQR model for different values of lam

# %%
# train our model
verbose = True

cqr_models = []
cqr_mfs = []
cqr_mus = []
for lam_ in lams:
    print('-- lam_:', lam_, '--')
    f = pred.PredModel(d, reg_type=reg_type, alpha=alpha_f, lr=lr_f, num_iter=num_iter_f, num_iter_init=num_iter_init)
    u = CQR(d, tau=(0.05, 0.95), lr=0.001, num_iter=5000, train_calib_split=0.5)
    h = prop.PropModel(random_state=seed)

    model = Lookahead(f, u, h, lam=lam_, eta=eta, mask=mask, ground_truth_model=fstar)
    mf, mu = model.train(x_trn, y_trn, num_cycles=num_cycles, random_state=seed, verbose=verbose)

    cqr_models.append(model)
    cqr_mfs.append(mf)
    cqr_mus.append(mu)
# Out:
# -- lam_: 1e-05 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0046, norm_reg: 0.0000, obj: 0.0046
# [u] size: 1.980, contain*: 0.976
# [f] mse: 0.0439, la_reg: 1.0280, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 2
# [h] n_eff: 34.91, w_sum: 37.75
# [u] loss: 0.0162, norm_reg: 0.0000, obj: 0.0162
# [u] size: 1.220, contain*: 0.976
# [f] mse: 0.0438, la_reg: 0.6811, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 3
# [h] n_eff: 34.92, w_sum: 37.84
# [u] loss: 0.0262, norm_reg: 0.0000, obj: 0.0262
# [u] size: 1.442, contain*: 0.976
# [f] mse: 0.0438, la_reg: 0.7786, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 4
# [h] n_eff: 34.93, w_sum: 37.90
# [u] loss: 0.0020, norm_reg: 0.0000, obj: 0.0020
# [u] size: 1.565, contain*: 1.000
# [f] mse: 0.0438, la_reg: 0.8278, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 5
# [h] n_eff: 34.93, w_sum: 37.94
# [u] loss: 0.0064, norm_reg: 0.0000, obj: 0.0064
# [u] size: 1.973, contain*: 1.000
# [f] mse: 0.0438, la_reg: 1.0092, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 6
# [h] n_eff: 34.93, w_sum: 37.96
# [u] loss: 0.0198, norm_reg: 0.0000, obj: 0.0198
# [u] size: 1.424, contain*: 1.000
# [f] mse: 0.0438, la_reg: 0.7653, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 7
# [h] n_eff: 34.93, w_sum: 37.98
# [u] loss: 0.0073, norm_reg: 0.0000, obj: 0.0073
# [u] size: 1.901, contain*: 1.000
# [f] mse: 0.0438, la_reg: 0.9764, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 8
# [h] n_eff: 34.93, w_sum: 37.99
# [u] loss: 0.0125, norm_reg: 0.0000, obj: 0.0125
# [u] size: 1.845, contain*: 1.000
# [f] mse: 0.0438, la_reg: 0.9380, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 9
# [h] n_eff: 34.93, w_sum: 38.00
# [u] loss: 0.0125, norm_reg: 0.0000, obj: 0.0125
# [u] size: 1.663, contain*: 1.000
# [f] mse: 0.0438, la_reg: 0.8749, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 10
# [h] n_eff: 34.93, w_sum: 38.01
# [u] loss: 0.0021, norm_reg: 0.0000, obj: 0.0021
# [u] size: 1.948, contain*: 1.000
# [f] mse: 0.0438, la_reg: 0.9954, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# -- lam_: 0.0625 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0116, norm_reg: 0.0000, obj: 0.0116
# [u] size: 1.516, contain*: 0.976
# [f] mse: 0.0439, la_reg: 0.7940, norm_reg: 0.0086, obj: 0.0978
# [f] improve*: 0.049
#
# t: 2
# [h] n_eff: 35.12, w_sum: 37.92
# [u] loss: 0.0095, norm_reg: 0.0000, obj: 0.0095
# [u] size: 1.842, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.9421, norm_reg: 0.0086, obj: 0.1071
# [f] improve*: 0.048
#
# t: 3
# [h] n_eff: 35.05, w_sum: 37.73
# [u] loss: 0.0022, norm_reg: 0.0000, obj: 0.0022
# [u] size: 1.690, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.8748, norm_reg: 0.0086, obj: 0.1029
# [f] improve*: 0.048
#
# t: 4
# [h] n_eff: 34.54, w_sum: 37.13
# [u] loss: 0.0077, norm_reg: 0.0000, obj: 0.0077
# [u] size: 1.683, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.8653, norm_reg: 0.0087, obj: 0.1023
# [f] improve*: 0.048
#
# t: 5
# [h] n_eff: 33.80, w_sum: 36.49
# [u] loss: 0.0149, norm_reg: 0.0000, obj: 0.0149
# [u] size: 1.585, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.8131, norm_reg: 0.0087, obj: 0.0991
# [f] improve*: 0.049
#
# t: 6
# [h] n_eff: 33.21, w_sum: 35.84
# [u] loss: 0.0131, norm_reg: 0.0000, obj: 0.0131
# [u] size: 1.734, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.8798, norm_reg: 0.0088, obj: 0.1033
# [f] improve*: 0.049
#
# t: 7
# [h] n_eff: 32.44, w_sum: 34.97
# [u] loss: 0.0072, norm_reg: 0.0000, obj: 0.0072
# [u] size: 1.639, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.8361, norm_reg: 0.0088, obj: 0.1006
# [f] improve*: 0.049
#
# t: 8
# [h] n_eff: 31.87, w_sum: 34.32
# [u] loss: 0.0019, norm_reg: 0.0000, obj: 0.0019
# [u] size: 1.915, contain*: 1.000
# [f] mse: 0.0440, la_reg: 0.9527, norm_reg: 0.0089, obj: 0.1080
# [f] improve*: 0.049
#
# t: 9
# [h] n_eff: 30.67, w_sum: 32.69
# [u] loss: 0.0244, norm_reg: 0.0000, obj: 0.0244
# [u] size: 1.898, contain*: 1.000
# [f] mse: 0.0440, la_reg: 0.9409, norm_reg: 0.0090, obj: 0.1073
# [f] improve*: 0.049
#
# t: 10
# [h] n_eff: 29.53, w_sum: 31.29
# [u] loss: 0.0082, norm_reg: 0.0000, obj: 0.0082
# [u] size: 1.864, contain*: 1.000
# [f] mse: 0.0440, la_reg: 0.9238, norm_reg: 0.0091, obj: 0.1063
# [f] improve*: 0.049
#
# -- lam_: 0.125 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0140, norm_reg: 0.0000, obj: 0.0140
# [u] size: 1.561, contain*: 1.000
# [f] mse: 0.0440, la_reg: 0.8193, norm_reg: 0.0085, obj: 0.1507
# [f] improve*: 0.047
#
# t: 2
# [h] n_eff: 34.48, w_sum: 36.40
# [u] loss: 0.0180, norm_reg: 0.0000, obj: 0.0180
# [u] size: 1.548, contain*: 1.000
# [f] mse: 0.0441, la_reg: 0.8129, norm_reg: 0.0085, obj: 0.1500
# [f] improve*: 0.046
#
# t: 3
# [h] n_eff: 32.84, w_sum: 33.90
# [u] loss: 0.0310, norm_reg: 0.0000, obj: 0.0310
# [u] size: 1.014, contain*: 1.000
# [f] mse: 0.0442, la_reg: 0.5706, norm_reg: 0.0085, obj: 0.1198
# [f] improve*: 0.046
#
# t: 4
# [h] n_eff: 31.79, w_sum: 31.16
# [u] loss: 0.0025, norm_reg: 0.0000, obj: 0.0025
# [u] size: 1.464, contain*: 1.000
# [f] mse: 0.0445, la_reg: 0.7632, norm_reg: 0.0087, obj: 0.1442
# [f] improve*: 0.045
#
# t: 5
# [h] n_eff: 29.49, w_sum: 25.09
# [u] loss: 0.0103, norm_reg: 0.0000, obj: 0.0103
# [u] size: 1.699, contain*: 1.000
# [f] mse: 0.0450, la_reg: 0.8529, norm_reg: 0.0091, obj: 0.1562
# [f] improve*: 0.044
#
# t: 6
# [h] n_eff: 27.06, w_sum: 17.85
# [u] loss: 0.0023, norm_reg: 0.0000, obj: 0.0023
# [u] size: 1.866, contain*: 1.000
# [f] mse: 0.0457, la_reg: 0.8994, norm_reg: 0.0098, obj: 0.1631
# [f] improve*: 0.043
#
# t: 7
# [h] n_eff: 26.18, w_sum: 11.97
# [u] loss: 0.0078, norm_reg: 0.0000, obj: 0.0078
# [u] size: 1.885, contain*: 1.000
# [f] mse: 0.0468, la_reg: 0.8808, norm_reg: 0.0108, obj: 0.1623
# [f] improve*: 0.043
#
# t: 8
# [h] n_eff: 26.37, w_sum: 8.18
# [u] loss: 0.0067, norm_reg: 0.0000, obj: 0.0067
# [u] size: 1.923, contain*: 1.000
# [f] mse: 0.0482, la_reg: 0.8563, norm_reg: 0.0122, obj: 0.1613
# [f] improve*: 0.043
#
# t: 9
# [h] n_eff: 27.04, w_sum: 5.79
# [u] loss: 0.0017, norm_reg: 0.0000, obj: 0.0017
# [u] size: 2.437, contain*: 1.000
# [f] mse: 0.0499, la_reg: 1.0463, norm_reg: 0.0141, obj: 0.1877
# [f] improve*: 0.043
#
# t: 10
# [h] n_eff: 27.95, w_sum: 4.28
# [u] loss: 0.0094, norm_reg: 0.0000, obj: 0.0094
# [u] size: 2.122, contain*: 1.000
# [f] mse: 0.0504, la_reg: 0.8849, norm_reg: 0.0150, obj: 0.1685
# [f] improve*: 0.044
#
# -- lam_: 0.25 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0063, norm_reg: 0.0000, obj: 0.0063
# [u] size: 2.117, contain*: 1.000
# [f] mse: 0.0451, la_reg: 1.0552, norm_reg: 0.0089, obj: 0.3134
# [f] improve*: 0.039
#
# t: 2
# [h] n_eff: 33.75, w_sum: 36.96
# [u] loss: 0.0204, norm_reg: 0.0000, obj: 0.0204
# [u] size: 1.547, contain*: 1.000
# [f] mse: 0.0446, la_reg: 0.8031, norm_reg: 0.0090, obj: 0.2499
# [f] improve*: 0.042
#
# t: 3
# [h] n_eff: 31.53, w_sum: 35.28
# [u] loss: 0.0126, norm_reg: 0.0000, obj: 0.0126
# [u] size: 1.458, contain*: 1.000
# [f] mse: 0.0451, la_reg: 0.7556, norm_reg: 0.0093, obj: 0.2387
# [f] improve*: 0.042
#
# t: 4
# [h] n_eff: 26.88, w_sum: 27.16
# [u] loss: 0.0179, norm_reg: 0.0000, obj: 0.0179
# [u] size: 1.806, contain*: 1.000
# [f] mse: 0.0465, la_reg: 0.8926, norm_reg: 0.0101, obj: 0.2747
# [f] improve*: 0.041
#
# t: 5
# [h] n_eff: 24.61, w_sum: 16.97
# [u] loss: 0.0091, norm_reg: 0.0000, obj: 0.0091
# [u] size: 1.939, contain*: 1.000
# [f] mse: 0.0486, la_reg: 0.9153, norm_reg: 0.0114, obj: 0.2832
# [f] improve*: 0.039
#
# t: 6
# [h] n_eff: 24.38, w_sum: 9.62
# [u] loss: 0.0080, norm_reg: 0.0000, obj: 0.0080
# [u] size: 1.789, contain*: 1.000
# [f] mse: 0.0516, la_reg: 0.8012, norm_reg: 0.0139, obj: 0.2588
# [f] improve*: 0.040
#
# t: 7
# [h] n_eff: 25.40, w_sum: 5.58
# [u] loss: 0.0169, norm_reg: 0.0000, obj: 0.0169
# [u] size: 2.062, contain*: 1.000
# [f] mse: 0.0548, la_reg: 0.8824, norm_reg: 0.0168, obj: 0.2838
# [f] improve*: 0.042
#
# t: 8
# [h] n_eff: 26.76, w_sum: 3.67
# [u] loss: 0.0146, norm_reg: 0.0000, obj: 0.0146
# [u] size: 1.422, contain*: 1.000
# [f] mse: 0.0590, la_reg: 0.5469, norm_reg: 0.0212, obj: 0.2063
# [f] improve*: 0.045
#
# t: 9
# [h] n_eff: 28.35, w_sum: 2.47
# [u] loss: 0.0022, norm_reg: 0.0000, obj: 0.0022
# [u] size: 2.212, contain*: 1.000
# [f] mse: 0.0617, la_reg: 0.8804, norm_reg: 0.0246, obj: 0.2940
# [f] improve*: 0.046
#
# t: 10
# [h] n_eff: 29.68, w_sum: 1.96
# [u] loss: 0.0021, norm_reg: 0.0000, obj: 0.0021
# [u] size: 2.121, contain*: 1.000
# [f] mse: 0.0651, la_reg: 0.7634, norm_reg: 0.0288, obj: 0.2703
# [f] improve*: 0.046
#
# -- lam_: 0.5 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0209, norm_reg: 0.0000, obj: 0.0209
# [u] size: 2.170, contain*: 0.976
# [f] mse: 0.0462, la_reg: 1.0956, norm_reg: 0.0089, obj: 0.5985
# [f] improve*: 0.036
#
# t: 2
# [h] n_eff: 34.28, w_sum: 36.60
# [u] loss: 0.0086, norm_reg: 0.0000, obj: 0.0086
# [u] size: 2.141, contain*: 1.000
# [f] mse: 0.0484, la_reg: 1.0912, norm_reg: 0.0092, obj: 0.5986
# [f] improve*: 0.028
#
# t: 3
# [h] n_eff: 32.56, w_sum: 34.89
# [u] loss: 0.0160, norm_reg: 0.0000, obj: 0.0160
# [u] size: 2.325, contain*: 1.000
# [f] mse: 0.0507, la_reg: 1.1645, norm_reg: 0.0096, obj: 0.6377
# [f] improve*: 0.022
#
# t: 4
# [h] n_eff: 28.40, w_sum: 30.85
# [u] loss: 0.0227, norm_reg: 0.0000, obj: 0.0227
# [u] size: 2.010, contain*: 1.000
# [f] mse: 0.0546, la_reg: 0.9726, norm_reg: 0.0116, obj: 0.5467
# [f] improve*: 0.025
#
# t: 5
# [h] n_eff: 17.64, w_sum: 18.10
# [u] loss: 0.0074, norm_reg: 0.0000, obj: 0.0074
# [u] size: 1.687, contain*: 1.000
# [f] mse: 0.0649, la_reg: 0.7873, norm_reg: 0.0155, obj: 0.4663
# [f] improve*: 0.025
#
# t: 6
# [h] n_eff: 15.90, w_sum: 9.34
# [u] loss: 0.0072, norm_reg: 0.0000, obj: 0.0072
# [u] size: 2.211, contain*: 1.000
# [f] mse: 0.0789, la_reg: 0.9401, norm_reg: 0.0208, obj: 0.5593
# [f] improve*: 0.026
#
# t: 7
# [h] n_eff: 16.50, w_sum: 5.06
# [u] loss: 0.0082, norm_reg: 0.0000, obj: 0.0082
# [u] size: 2.091, contain*: 1.000
# [f] mse: 0.0911, la_reg: 0.8121, norm_reg: 0.0266, obj: 0.5104
# [f] improve*: 0.030
#
# t: 8
# [h] n_eff: 19.06, w_sum: 2.91
# [u] loss: 0.0072, norm_reg: 0.0000, obj: 0.0072
# [u] size: 2.077, contain*: 1.000
# [f] mse: 0.0946, la_reg: 0.7898, norm_reg: 0.0308, obj: 0.5049
# [f] improve*: 0.035
#
# t: 9
# [h] n_eff: 22.11, w_sum: 2.06
# [u] loss: 0.0075, norm_reg: 0.0000, obj: 0.0075
# [u] size: 2.080, contain*: 1.000
# [f] mse: 0.1003, la_reg: 0.7522, norm_reg: 0.0372, obj: 0.4950
# [f] improve*: 0.040
#
# t: 10
# [h] n_eff: 24.79, w_sum: 1.50
# [u] loss: 0.0142, norm_reg: 0.0000, obj: 0.0142
# [u] size: 2.181, contain*: 1.000
# [f] mse: 0.1113, la_reg: 0.7114, norm_reg: 0.0455, obj: 0.4898
# [f] improve*: 0.044
#
# -- lam_: 1.0 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0053, norm_reg: 0.0000, obj: 0.0053
# [u] size: 1.619, contain*: 1.000
# [f] mse: 0.0560, la_reg: 0.8143, norm_reg: 0.0118, obj: 0.8762
# [f] improve*: 0.022
#
# t: 2
# [h] n_eff: 20.45, w_sum: 23.80
# [u] loss: 0.0153, norm_reg: 0.0000, obj: 0.0153
# [u] size: 2.234, contain*: 1.000
# [f] mse: 0.1179, la_reg: 0.9122, norm_reg: 0.0296, obj: 1.0450
# [f] improve*: -0.007
#
# t: 3
# [h] n_eff: 22.24, w_sum: 2.15
# [u] loss: 0.0243, norm_reg: 0.0000, obj: 0.0243
# [u] size: 1.350, contain*: 0.976
# [f] mse: 0.1476, la_reg: 0.3178, norm_reg: 0.0640, obj: 0.4973
# [f] improve*: 0.023
#
# t: 4
# [h] n_eff: 30.90, w_sum: 0.73
# [u] loss: 0.0091, norm_reg: 0.0000, obj: 0.0091
# [u] size: 1.991, contain*: 0.857
# [f] mse: 0.1769, la_reg: 0.2913, norm_reg: 0.1141, obj: 0.5253
# [f] improve*: 0.064
#
# t: 5
# [h] n_eff: 34.92, w_sum: 0.40
# [u] loss: 0.0079, norm_reg: 0.0000, obj: 0.0079
# [u] size: 2.358, contain*: 0.786
# [f] mse: 0.1841, la_reg: 0.2664, norm_reg: 0.1428, obj: 0.5219
# [f] improve*: 0.097
#
# t: 6
# [h] n_eff: 36.14, w_sum: 0.32
# [u] loss: 0.0191, norm_reg: 0.0000, obj: 0.0191
# [u] size: 2.479, contain*: 0.714
# [f] mse: 0.1937, la_reg: 0.2450, norm_reg: 0.1591, obj: 0.5182
# [f] improve*: 0.108
#
# t: 7
# [h] n_eff: 36.56, w_sum: 0.29
# [u] loss: 0.0083, norm_reg: 0.0000, obj: 0.0083
# [u] size: 2.454, contain*: 0.357
# [f] mse: 0.1757, la_reg: 0.2123, norm_reg: 0.1541, obj: 0.4650
# [f] improve*: 0.117
#
# t: 8
# [h] n_eff: 36.72, w_sum: 0.30
# [u] loss: 0.0022, norm_reg: 0.0000, obj: 0.0022
# [u] size: 2.120, contain*: 0.190
# [f] mse: 0.1483, la_reg: 0.1895, norm_reg: 0.1300, obj: 0.4028
# [f] improve*: 0.111
#
# t: 9
# [h] n_eff: 36.42, w_sum: 0.35
# [u] loss: 0.0022, norm_reg: 0.0000, obj: 0.0022
# [u] size: 2.365, contain*: 0.762
# [f] mse: 0.1836, la_reg: 0.2228, norm_reg: 0.1467, obj: 0.4798
# [f] improve*: 0.106
#
# t: 10
# [h] n_eff: 36.15, w_sum: 0.32
# [u] loss: 0.0063, norm_reg: 0.0000, obj: 0.0063
# [u] size: 2.448, contain*: 0.333
# [f] mse: 0.1751, la_reg: 0.2158, norm_reg: 0.1475, obj: 0.4647
# [f] improve*: 0.111
#
# -- lam_: 2.0 --
# t: 0
# [f] mse: 0.0439, la_reg: 0.0000, norm_reg: 0.0086, obj: 0.0482
# [f] improve*: 0.051
#
# t: 1
# [h] n_eff: 34.90, w_sum: 37.60
# [u] loss: 0.0172, norm_reg: 0.0000, obj: 0.0172
# [u] size: 1.996, contain*: 1.000
# [f] mse: 0.1833, la_reg: 0.8937, norm_reg: 0.0302, obj: 1.9859
# [f] improve*: -0.071
#
# t: 2
# [h] n_eff: 12.04, w_sum: 3.37
# [u] loss: 0.0093, norm_reg: 0.0000, obj: 0.0093
# [u] size: 2.509, contain*: 1.000
# [f] mse: 0.4027, la_reg: 0.9000, norm_reg: 0.0637, obj: 2.2346
# [f] improve*: -0.109
#
# t: 3
# [h] n_eff: 14.88, w_sum: 1.07
# [u] loss: 0.0096, norm_reg: 0.0000, obj: 0.0096
# [u] size: 2.330, contain*: 1.000
# [f] mse: 0.5990, la_reg: 0.5072, norm_reg: 0.1097, obj: 1.6682
# [f] improve*: -0.109
#
# t: 4
# [h] n_eff: 21.75, w_sum: 0.50
# [u] loss: 0.0151, norm_reg: 0.0000, obj: 0.0151
# [u] size: 2.276, contain*: 0.500
# [f] mse: 0.4600, la_reg: 0.3300, norm_reg: 0.1282, obj: 1.1840
# [f] improve*: -0.007
#
# t: 5
# [h] n_eff: 27.23, w_sum: 0.40
# [u] loss: 0.0222, norm_reg: 0.0000, obj: 0.0222
# [u] size: 2.616, contain*: 0.952
# [f] mse: 0.5329, la_reg: 0.3409, norm_reg: 0.2013, obj: 1.3152
# [f] improve*: 0.078
#
# t: 6
# [h] n_eff: 31.48, w_sum: 0.26
# [u] loss: 0.0088, norm_reg: 0.0000, obj: 0.0088
# [u] size: 2.260, contain*: 0.095
# [f] mse: 0.3272, la_reg: 0.2452, norm_reg: 0.1977, obj: 0.9166
# [f] improve*: 0.124
#
# t: 7
# [h] n_eff: 34.66, w_sum: 0.25
# [u] loss: 0.0190, norm_reg: 0.0000, obj: 0.0190
# [u] size: 2.209, contain*: 0.762
# [f] mse: 0.3356, la_reg: 0.2470, norm_reg: 0.2152, obj: 0.9373
# [f] improve*: 0.128
#
# t: 8
# [h] n_eff: 35.47, w_sum: 0.23
# [u] loss: 0.0286, norm_reg: 0.0000, obj: 0.0286
# [u] size: 2.356, contain*: 0.667
# [f] mse: 0.3381, la_reg: 0.2378, norm_reg: 0.2302, obj: 0.9288
# [f] improve*: 0.136
#
# t: 9
# [h] n_eff: 36.05, w_sum: 0.22
# [u] loss: 0.0026, norm_reg: 0.0000, obj: 0.0026
# [u] size: 2.546, contain*: 0.881
# [f] mse: 0.3914, la_reg: 0.2639, norm_reg: 0.2602, obj: 1.0494
# [f] improve*: 0.146
#
# t: 10
# [h] n_eff: 36.25, w_sum: 0.19
# [u] loss: 0.0218, norm_reg: 0.0000, obj: 0.0218
# [u] size: 2.455, contain*: 0.524
# [f] mse: 0.3469, la_reg: 0.2290, norm_reg: 0.2555, obj: 0.9325
# [f] improve*: 0.153

# %%
cqr_mus = np.asarray(cqr_mus)
cqr_mfs = np.asarray(cqr_mfs)

# %% [markdown]
# # Evaluating the performance of the trained lookahead + CQR models

# %%
# evaluate

cqr_perf_la = {'mse':[], 'mae':[], 'improve':[], 'contain':[], 'size':[]}
for lam, model in zip(lams,cqr_models):
    cqr_perf_la['mse'].append([model.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    cqr_perf_la['mae'].append([model.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    cqr_perf_la['improve'].append([model.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])

    xsp = [model.move_points(x_) for x_ in xs]
    cqr_perf_la['contain'].append([model.contain(x_)[0] for x_ in [*xsp, x]])
    cqr_perf_la['size'].append([model.contain(x_)[1] for x_ in [*xsp, x]])

cqr_perf_la = {k:np.asarray(v) for k,v in zip(cqr_perf_la.keys(),cqr_perf_la.values())}

print('lookahead: eta:', eta)
for i in range(len(lams)):
    print('\n==============================================\n')
    print('lam:', lams[i])
    print('\ttrn\tts\tactv\tall\tf*')
    print(('mse'+'\t{:.4f}'*5).format(*cqr_perf_la['mse'][i,:], mse_star))
    print(('mae'+'\t{:.4f}'*5).format(*cqr_perf_la['mae'][i,:], mae_star))
    print(('imprv'+'\t{:.4f}'*4).format(*cqr_perf_la['improve'][i,:]))
    print()
    print('\ttrn\'\ttst\'\tactv\'\tall\'\tall')
    print(('contn'+'\t{:.3f}'*5).format(*cqr_perf_la['contain'][i,:]))
    print(('intrsz'+'\t{:.3f}'*5).format(*cqr_perf_la['size'][i,:]))
# Out:
# lookahead: eta: 2.0
#
# ==============================================
#
# lam: 1e-05
# 	trn	ts	actv	all	f*
# mse	0.0438	0.0580	0.0476	0.1046	0.0411
# mae	0.1696	0.1794	0.1722	0.2532	0.1627
# imprv	0.0507	-0.0148	0.0335	0.0078
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.949	0.949
# intrsz	1.944	1.934	1.941	2.064	2.057
#
# ==============================================
#
# lam: 0.0625
# 	trn	ts	actv	all	f*
# mse	0.0440	0.0534	0.0465	0.1713	0.0411
# mae	0.1691	0.1650	0.1680	0.3260	0.1627
# imprv	0.0492	-0.0162	0.0320	0.0062
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.938	0.927
# intrsz	1.867	1.850	1.864	2.039	2.013
#
# ==============================================
#
# lam: 0.125
# 	trn	ts	actv	all	f*
# mse	0.0504	0.0482	0.0498	0.8683	0.0411
# mae	0.1816	0.1630	0.1767	0.6852	0.1627
# imprv	0.0441	-0.0219	0.0268	-0.0019
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.978	0.961
# intrsz	2.131	2.109	2.126	2.313	2.207
#
# ==============================================
#
# lam: 0.25
# 	trn	ts	actv	all	f*
# mse	0.0651	0.0495	0.0610	2.0119	0.0411
# mae	0.2061	0.1787	0.1989	1.0286	0.1627
# imprv	0.0464	-0.0193	0.0291	-0.0013
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.994	0.949
# intrsz	2.139	2.096	2.130	2.325	2.131
#
# ==============================================
#
# lam: 0.5
# 	trn	ts	actv	all	f*
# mse	0.1113	0.0912	0.1060	3.2393	0.0411
# mae	0.2730	0.2322	0.2623	1.3672	0.1627
# imprv	0.0436	-0.0205	0.0267	-0.0007
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.989	0.978
# intrsz	2.203	2.156	2.187	2.401	2.197
#
# ==============================================
#
# lam: 1.0
# 	trn	ts	actv	all	f*
# mse	0.1750	0.1819	0.1768	11.1250	0.0411
# mae	0.3386	0.3539	0.3426	2.3553	0.1627
# imprv	0.1115	0.0481	0.0948	0.0512
#
# 	trn'	tst'	actv'	all'	all
# contn	0.500	0.667	0.596	0.815	0.899
# intrsz	2.430	2.363	2.418	2.581	1.990
#
# ==============================================
#
# lam: 2.0
# 	trn	ts	actv	all	f*
# mse	0.3463	0.4241	0.3668	19.1341	0.0411
# mae	0.4570	0.5109	0.4712	3.1584	0.1627
# imprv	0.1534	0.0925	0.1373	0.0929
#
# 	trn'	tst'	actv'	all'	all
# contn	0.595	0.800	0.684	0.820	0.972
# intrsz	2.417	2.375	2.409	2.684	2.137

# %% [markdown]
# ## Training the baseline model for different values of l2 - regularizer coefficient

# %%
verbose = False

models_base = []
for alpha in alphas:
    f_base = pred.PredModel(d, reg_type=reg_type, alpha=alpha, lr=lr_f, num_iter_init=num_iter_init)
    model_base = Lookahead(f_base, None, None, lam=0., eta=eta, mask=mask, ground_truth_model=fstar)
    _, _ = model_base.train(x_trn, y_trn, num_cycles=0, random_state=seed, verbose=verbose)
    models_base.append(model_base)

perf_base = {'mse':[], 'mae':[], 'improve':[]} #, 'contain':[], 'size':[]}
for model in models_base:
    perf_base['mse'].append([model.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_base['mae'].append([model.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_base['improve'].append([model.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])
perf_base = {k:np.asarray(v) for k,v in zip(perf_base.keys(),perf_base.values())}

# %% [markdown]
# # Comparing the performance of lookahead regularizer vs the l2- regularizer
# We compare the performace of our lookahead model for various values of lam
# with the performance of the baseline model for various values of the l2-regularizer coefficient

# %%
SAVE_FIG = False
fname = 'wine_mask_la+l2'

print('seed:',seed,', eta:',eta)

plt.rcParams['figure.figsize'] = (16.0, 5.0)
plt.subplot(121)
plt.plot(perf_base['improve'][:,1], perf_base['mse'][:,1],'b-x')
plt.plot(perf_la['improve'][:,1], perf_la['mse'][:,1],'g-x')
plt.plot(cqr_perf_la['improve'][:,1], cqr_perf_la['mse'][:,1],'m-x')
# plt.plot(perf_naive['improve'][:,1], perf_naive['mse'][:,1],'g-x')
plt.title('frontier - test')
plt.ylabel('mse')
plt.xlabel('improve')
# plt.legend(['base (alpha)','la (lambda)', 'naive (step size)'])
plt.legend(['base (alpha)','la (lambda)', 'la + cqr (lambda)'])
plt.grid()
plt.ylim([0.,0.18])
plt.xlim([-0.04,0.1])

plt.subplot(122)
plt.plot(perf_base['improve'][:,0], perf_base['mse'][:,0],'b-x')
plt.plot(perf_la['improve'][:,0], perf_la['mse'][:,0],'g-x')
plt.plot(cqr_perf_la['improve'][:,0], cqr_perf_la['mse'][:,0],'m-x')
# plt.plot(perf_naive['improve'][:,0], perf_naive['mse'][:,0],'g-x')
plt.title('frontier - train')
plt.ylabel('mse')
plt.xlabel('improve')
# plt.legend(['base (alpha)','la (lambda)','naive (step size)'])
plt.legend(['base (alpha)','la (lambda)', 'la + cqr (lambda)'])
plt.grid()
plt.ylim([0.,0.18])

if SAVE_FIG:
    plt.draw()
    plt.savefig(fname+'.eps', format='eps')
    plt.savefig(fname+'.png', format='png', dpi=300)
    print('saved ' + fname)

else:
    plt.show()
# Out:
# seed: 1 , eta: 2.0

# %% [markdown]
# ## Effect of varying the lookahead regularizer coefficient
# This plot shows how weights learned vary with increase in lam

# %%
ws_la_cqr = np.asarray([m.f.model.linear.weight.detach().numpy().squeeze() for m in cqr_models])
ws_la = np.asarray([m.f.model.linear.weight.detach().numpy().squeeze() for m in models])
ws_base = np.asarray([m.f.model.linear.weight.detach().numpy().squeeze() for m in models_base])

mask_idx = np.where(mask>0)[0]
non_mask_idx = np.setdiff1d(np.arange(d), mask_idx)

plt.rcParams['figure.figsize'] = (16.0, 10.0)
plt.plot(np.arange(len(lams))+0.5,ws_la[:,mask_idx],'x-', c='g')
plt.plot(np.arange(len(lams))+0.5,ws_la[:,non_mask_idx],'-', c='g')

plt.plot(np.arange(len(lams))+0.5,ws_la_cqr[:,mask_idx],'x-', c='m')
plt.plot(np.arange(len(lams))+0.5,ws_la_cqr[:,non_mask_idx],'-', c='m')

plt.gca().set_prop_cycle(None)
for i in range(len(w_bench)):
    plt.plot(0,w_bench[i],'o')

plt.gca().set_prop_cycle(None)
plt.plot(np.arange(0,-len(alphas),-1)-0.5,ws_base,'-.')
plt.legend([str(i) for i in range(d)])
plt.grid()
plt.ylim([-0.4,0.4])
plt.show()

# %% [markdown]
# This plot shows how coverage rate and interval size vary with increasing lam

# %%
plt.rcParams['figure.figsize'] = (16.0, 5.0)

plt.subplot(121)

plt.plot(np.arange(len(lams)), perf_la['contain'][:,:2],'x-', c='g')
plt.plot(np.arange(len(lams)), cqr_perf_la['contain'][:,:2],'x-', c='m')

plt.title('la coverage rate')
plt.ylabel('coverage rate')
plt.xlabel('lambda')
plt.xticks(np.arange(len(lams)),lams)
plt.legend(['la: train','la: test', 'la+cqr: train','la+cqr: test'])

plt.subplot(122)
plt.plot(np.arange(len(lams)), perf_la['size'][:,:2],'x-', c='g')
plt.plot(np.arange(len(lams)), cqr_perf_la['size'][:,:2],'x-', c='m')

plt.title('la interval size')
plt.ylabel('interval size')
plt.xlabel('lambda')
plt.xticks(np.arange(len(lams)),lams)
plt.legend(['la: train','la: test', 'la+cqr: train','la+cqr: test'])
plt.show()
