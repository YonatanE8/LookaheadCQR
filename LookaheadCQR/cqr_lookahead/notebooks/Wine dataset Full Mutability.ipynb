# %%
import torch
import numpy as np
from collections import OrderedDict
from matplotlib import pyplot as plt

from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV
from LookaheadCQR.cqr_lookahead.uncertainty import CQR

from LookaheadCQR.lookahead.models.lookahead import Lookahead
import LookaheadCQR.lookahead.models.uncertainty as uncert
import LookaheadCQR.lookahead.models.prediction as pred
import LookaheadCQR.lookahead.models.propensity as prop

# %matplotlib inline
np.set_printoptions(precision=3)

# %% [markdown]
# ## Loading the wine data

# %%
#load data
x,y0 = data = load_wine(return_X_y=True)
scaler = StandardScaler()
scaler.fit(x)
scaler.transform(x, copy=False)
n = x.shape[0]
d = x.shape[1]

# %% [markdown]
# ## Defining the groundtruth model.
# Here we choose Ridge Regression with polynomial features (degree =2) as the groundtruth function f* and
# select the best model using 5 - fold cross validation.

# %%
class Fstar():
    def __init__(self):
        self.model = RidgeCV(alphas=alpha_range)
    def fit(self, x, y):
        x2 = np.hstack([x, 0.5*x**2]).round(3)
        self.model.fit(x2, y)
    def predict(self, x):
        x2 = np.hstack([x, 0.5*x**2]).round(3)
        return self.model.predict(x2)

# %%
# Hyperparamters for the ground truth model
C_range = 2. ** np.arange(-8,10,2)
gamma_range = 2. ** np.arange(-10,3,2)
alpha_range = 2.**np.arange(-8,8)
param_grid = {'gamma':gamma_range, 'C':C_range}

# Train the model
fstar = Fstar()
fstar.fit(x, y0)
y = fstar.predict(x)
mse_star = np.mean(np.square(y-y0))
mae_star = np.mean(np.abs(y-y0))
print("[f*] mse(y,y0):", mse_star)
print("[f*] mae(y,y0):", mae_star)
# Out:
# [f*] mse(y,y0): 0.04106275149850199
# [f*] mae(y,y0): 0.1626729186916224

# %% [markdown]
# ## Visualizing the features.
# Features 0,1 have non-linaer relation to y

# %%
plt.rcParams['figure.figsize'] = (12.0, 4.0)

plt.subplot(121)
plt.scatter(x[:,0], y, s=10)
plt.xlabel('x0')
plt.ylabel('y')

plt.subplot(122)
plt.scatter(x[:,1], y, s=10)
plt.xlabel('x1')
plt.ylabel('y')
plt.show()


# np.corrcoef(x_trn[:,i],y_trn[:])[0,1]

# %%
# split data
trn_sz = 0.75
seed = 1

active = np.where(np.logical_and(x[:,0]>=-0.2,x[:,1]<=-0.3))[0]

x_active = x[active,:]
y_active = y0[active]
n_active = y_active.shape[0]

x_trn, x_tst, y_trn, y_tst = train_test_split(x_active, y_active, test_size=1-trn_sz, random_state=seed)
n_trn, n_tst = (x_trn.shape[0], x_tst.shape[0])
print('n:', n, ', n_active:', n_active, ", n_trn:", n_trn, ", n_tst:", n_tst)

xs = [x_trn, x_tst, x_active, x]
ys = [y_trn, y_tst, y_active, y]
# Out:
# n: 178 , n_active: 57 , n_trn: 42 , n_tst: 15

# %% [markdown]
# ## Setting the hyperparamters of the look ahead model

# %%
# Step Size
eta = 0.5

# L2 regularization coefficients
alphas = np.hstack([1e-5, 2.**np.arange(-8,6,1)])

# Lookahead regularization coefficient
lams = np.hstack([1e-5, 2.**np.arange(-4,2,1)]) #lookahead penalty coefficients

# Setting features that can by altered using mask
# Features - 0, 1, 4, 5, 7 and 8 are the only non-immutable features
mask = np.ones(d)

# Number of cycles to train
num_cycles = 10

# Confidence Intervals
z_score = 1.65 # for confiednce intervals (1.28-90%, 1.65=95%)

""" Hyperparameters for Prediction Model"""
# L2 - regularization coeffs
alpha_f = 0.5
# Regularization type (L1/L2)
reg_type = 'l2'
# Learning rate
lr_f = 0.1
# Number of iterations
num_iter_init = 1000 #for initial f
num_iter_f = 100 #for training f in cycles

""" Hyperparameters for Uncertainty Model"""
# Number of bootstrapped models
num_gs = 20
# Learning rate
lr_g = 0.1
# Number of iterations
num_iter_g = 5000 #for training g in cycles

# %% [markdown]
# ## Training a baseline model and displaying the weights learnt and the result

# %%
# baselines
verbose = False

# scikitlearn - to get optimal regularization coefficient via CV)
f_base_skl = RidgeCV(alphas=alphas, cv=None).fit(x_trn, y_trn)
w_base_skl = f_base_skl.coef_
best_alpha = float(f_base_skl.alpha_)
best_alpha_idx = int(np.where(alphas==best_alpha)[0])

# benchmark trained on all data
f_bench = RidgeCV(alphas=alphas, cv=None).fit(x, y)
w_bench = f_bench.coef_

# ours - for sanity check (vs SKL) and to get baseline improvement
f_base = pred.PredModel(d, reg_type='l2', alpha=best_alpha, lr=lr_f, num_iter_init=num_iter_init)
model_base = Lookahead(f_base, None, None, lam=0., eta=eta, mask=mask, ground_truth_model=fstar)
_, _ = model_base.train(x_trn, y_trn, num_cycles=0, random_state=seed, verbose=verbose)

plt.rcParams['figure.figsize'] = (14.0, 3.0)
barWidth = 0.35
plt.bar(np.arange(d)-barWidth/2,w_base_skl/np.sum(np.abs(w_base_skl)),alpha=0.6,width=barWidth)
plt.bar(np.arange(d)+barWidth/2,w_bench/np.sum(np.abs(w_bench)),alpha=0.6,width=barWidth)
plt.xticks(np.arange(d))
plt.title('model parameters')
plt.ylabel('value')
plt.xlabel('feature number')
plt.legend(['train data','all data'])
plt.grid()
plt.show()

perf_base_skl = {'mse':[], 'mae':[]}
for x_,y_ in zip(xs, ys):
    yhat_ = f_base_skl.predict(x_)
    perf_base_skl['mse'].append(np.mean(np.square(y_-yhat_)))
    perf_base_skl['mae'].append(np.mean(np.abs(y_-yhat_)))
print('baseline: (skl)')
print('\t\ttrn\ttst\tactv\tall')
print(('mse'+'\t{:.4f}'*4).format(*perf_base_skl['mse']))
print(('mae'+'\t{:.4f}'*4).format(*perf_base_skl['mae']))
print()

perf_base = {'mse':[], 'mae':[], 'improve':[]}
for x_,y_ in zip(xs, ys):
    perf_base['mse'].append(model_base.mse(x_,y_))
    perf_base['mae'].append(model_base.mae(x_,y_))
    perf_base['improve'].append(model_base.improve(x_,y_,eta,mask))
print('baseline: (ours)')
print('base:\ttrn\ttst\tactv\tall')
print(('mse'+'\t{:.4f}'*4).format(*perf_base['mse']))
print(('mae'+'\t{:.4f}'*4).format(*perf_base['mae']))
print(('imprv'+'\t{:.4f}'*4).format(*perf_base['improve']))
print()

print('best reg coef:', best_alpha, ', idx:', best_alpha_idx)
# Out:
# baseline: (skl)
# 		trn	tst	actv	all
# mse	0.0557	0.0511	0.0544	0.0780
# mae	0.1932	0.1750	0.1884	0.2229
#
# baseline: (ours)
# base:	trn	tst	actv	all
# mse	0.0557	0.0511	0.0544	0.0780
# mae	0.1932	0.1750	0.1884	0.2229
# imprv	0.1046	0.0303	0.0851	0.0851
#
# best reg coef: 8.0 , idx: 12

# %% [markdown]
# ## Training the lookahead model for different values of lam

# %%
# train our model
verbose = True

models = []
mfs = []
mus = []
for lam_ in lams:
    print('-- lam_:', lam_, '--')
    f = pred.PredModel(d, reg_type='none', alpha=0., lr=lr_f, num_iter=num_iter_f, num_iter_init=num_iter_init)
    u = uncert.BootstrapResid(d, f, alpha=0., num_gs=num_gs, z_score=z_score, lr=lr_g, num_iter=num_iter_g)
    h = prop.PropModel(random_state=seed)

    model = Lookahead(f, u, h, lam=lam_, eta=eta, mask=mask, ground_truth_model=fstar)
    mf, mu = model.train(x_trn, y_trn, num_cycles=num_cycles, random_state=seed, verbose=verbose)

    models.append(model)
    mfs.append(mf)
    mus.append(mu)

mus = np.asarray(mus)
mfs = np.asarray(mfs)
# Out:
# -- lam_: 1e-05 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0815, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 2
# [h] n_eff: 28.44, w_sum: 31.47
# [u] loss: 0.0661, norm_reg: 0.0000, obj: 0.0661
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0810, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 3
# [h] n_eff: 28.35, w_sum: 31.40
# [u] loss: 0.0659, norm_reg: 0.0000, obj: 0.0659
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0807, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 4
# [h] n_eff: 28.27, w_sum: 31.33
# [u] loss: 0.0658, norm_reg: 0.0000, obj: 0.0658
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0804, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 5
# [h] n_eff: 28.21, w_sum: 31.28
# [u] loss: 0.0657, norm_reg: 0.0000, obj: 0.0657
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0802, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 6
# [h] n_eff: 28.15, w_sum: 31.23
# [u] loss: 0.0656, norm_reg: 0.0000, obj: 0.0656
# [u] size: 0.489, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0800, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 7
# [h] n_eff: 28.11, w_sum: 31.19
# [u] loss: 0.0655, norm_reg: 0.0000, obj: 0.0655
# [u] size: 0.489, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0798, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 8
# [h] n_eff: 28.07, w_sum: 31.16
# [u] loss: 0.0654, norm_reg: 0.0000, obj: 0.0654
# [u] size: 0.489, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0797, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 9
# [h] n_eff: 28.04, w_sum: 31.13
# [u] loss: 0.0654, norm_reg: 0.0000, obj: 0.0654
# [u] size: 0.489, contain*: 0.762
# [f] mse: 0.0431, la_reg: 0.0796, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 10
# [h] n_eff: 28.02, w_sum: 31.10
# [u] loss: 0.0653, norm_reg: 0.0000, obj: 0.0653
# [u] size: 0.489, contain*: 0.762
# [f] mse: 0.0431, la_reg: 0.0795, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# -- lam_: 0.0625 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0431, la_reg: 0.0783, norm_reg: 0.0000, obj: 0.0480
# [f] improve*: 0.165
#
# t: 2
# [h] n_eff: 27.61, w_sum: 30.41
# [u] loss: 0.0654, norm_reg: 0.0000, obj: 0.0654
# [u] size: 0.499, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0775, norm_reg: 0.0000, obj: 0.0480
# [f] improve*: 0.167
#
# t: 3
# [h] n_eff: 27.13, w_sum: 29.76
# [u] loss: 0.0649, norm_reg: 0.0000, obj: 0.0649
# [u] size: 0.505, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0767, norm_reg: 0.0000, obj: 0.0480
# [f] improve*: 0.169
#
# t: 4
# [h] n_eff: 26.85, w_sum: 29.36
# [u] loss: 0.0645, norm_reg: 0.0000, obj: 0.0645
# [u] size: 0.508, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0760, norm_reg: 0.0000, obj: 0.0480
# [f] improve*: 0.169
#
# t: 5
# [h] n_eff: 26.67, w_sum: 29.10
# [u] loss: 0.0643, norm_reg: 0.0000, obj: 0.0643
# [u] size: 0.511, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0755, norm_reg: 0.0000, obj: 0.0479
# [f] improve*: 0.170
#
# t: 6
# [h] n_eff: 26.54, w_sum: 28.91
# [u] loss: 0.0641, norm_reg: 0.0000, obj: 0.0641
# [u] size: 0.512, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0751, norm_reg: 0.0000, obj: 0.0479
# [f] improve*: 0.170
#
# t: 7
# [h] n_eff: 26.46, w_sum: 28.79
# [u] loss: 0.0639, norm_reg: 0.0000, obj: 0.0639
# [u] size: 0.513, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0749, norm_reg: 0.0000, obj: 0.0479
# [f] improve*: 0.170
#
# t: 8
# [h] n_eff: 26.44, w_sum: 28.75
# [u] loss: 0.0639, norm_reg: 0.0000, obj: 0.0639
# [u] size: 0.513, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0747, norm_reg: 0.0000, obj: 0.0479
# [f] improve*: 0.170
#
# t: 9
# [h] n_eff: 26.40, w_sum: 28.70
# [u] loss: 0.0638, norm_reg: 0.0000, obj: 0.0638
# [u] size: 0.513, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0745, norm_reg: 0.0000, obj: 0.0479
# [f] improve*: 0.170
#
# t: 10
# [h] n_eff: 26.37, w_sum: 28.65
# [u] loss: 0.0637, norm_reg: 0.0000, obj: 0.0637
# [u] size: 0.513, contain*: 0.762
# [f] mse: 0.0432, la_reg: 0.0743, norm_reg: 0.0000, obj: 0.0479
# [f] improve*: 0.170
#
# -- lam_: 0.125 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0433, la_reg: 0.0752, norm_reg: 0.0000, obj: 0.0527
# [f] improve*: 0.170
#
# t: 2
# [h] n_eff: 26.85, w_sum: 29.37
# [u] loss: 0.0648, norm_reg: 0.0000, obj: 0.0648
# [u] size: 0.512, contain*: 0.762
# [f] mse: 0.0434, la_reg: 0.0744, norm_reg: 0.0000, obj: 0.0527
# [f] improve*: 0.173
#
# t: 3
# [h] n_eff: 26.10, w_sum: 28.22
# [u] loss: 0.0640, norm_reg: 0.0000, obj: 0.0640
# [u] size: 0.523, contain*: 0.762
# [f] mse: 0.0435, la_reg: 0.0736, norm_reg: 0.0000, obj: 0.0527
# [f] improve*: 0.175
#
# t: 4
# [h] n_eff: 25.78, w_sum: 27.65
# [u] loss: 0.0636, norm_reg: 0.0000, obj: 0.0636
# [u] size: 0.528, contain*: 0.762
# [f] mse: 0.0435, la_reg: 0.0726, norm_reg: 0.0000, obj: 0.0526
# [f] improve*: 0.176
#
# t: 5
# [h] n_eff: 25.56, w_sum: 27.26
# [u] loss: 0.0632, norm_reg: 0.0000, obj: 0.0632
# [u] size: 0.532, contain*: 0.762
# [f] mse: 0.0436, la_reg: 0.0719, norm_reg: 0.0000, obj: 0.0526
# [f] improve*: 0.176
#
# t: 6
# [h] n_eff: 25.42, w_sum: 26.98
# [u] loss: 0.0630, norm_reg: 0.0000, obj: 0.0630
# [u] size: 0.534, contain*: 0.762
# [f] mse: 0.0436, la_reg: 0.0713, norm_reg: 0.0000, obj: 0.0525
# [f] improve*: 0.177
#
# t: 7
# [h] n_eff: 25.31, w_sum: 26.76
# [u] loss: 0.0628, norm_reg: 0.0000, obj: 0.0628
# [u] size: 0.536, contain*: 0.762
# [f] mse: 0.0436, la_reg: 0.0708, norm_reg: 0.0000, obj: 0.0525
# [f] improve*: 0.177
#
# t: 8
# [h] n_eff: 25.24, w_sum: 26.59
# [u] loss: 0.0627, norm_reg: 0.0000, obj: 0.0627
# [u] size: 0.538, contain*: 0.762
# [f] mse: 0.0436, la_reg: 0.0704, norm_reg: 0.0000, obj: 0.0524
# [f] improve*: 0.177
#
# t: 9
# [h] n_eff: 25.18, w_sum: 26.46
# [u] loss: 0.0626, norm_reg: 0.0000, obj: 0.0626
# [u] size: 0.539, contain*: 0.762
# [f] mse: 0.0436, la_reg: 0.0702, norm_reg: 0.0000, obj: 0.0524
# [f] improve*: 0.177
#
# t: 10
# [h] n_eff: 25.16, w_sum: 26.40
# [u] loss: 0.0625, norm_reg: 0.0000, obj: 0.0625
# [u] size: 0.539, contain*: 0.762
# [f] mse: 0.0436, la_reg: 0.0701, norm_reg: 0.0000, obj: 0.0524
# [f] improve*: 0.177
#
# -- lam_: 0.25 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0437, la_reg: 0.0712, norm_reg: 0.0000, obj: 0.0615
# [f] improve*: 0.176
#
# t: 2
# [h] n_eff: 25.75, w_sum: 27.74
# [u] loss: 0.0639, norm_reg: 0.0000, obj: 0.0639
# [u] size: 0.533, contain*: 0.762
# [f] mse: 0.0442, la_reg: 0.0701, norm_reg: 0.0000, obj: 0.0617
# [f] improve*: 0.182
#
# t: 3
# [h] n_eff: 24.73, w_sum: 25.82
# [u] loss: 0.0629, norm_reg: 0.0000, obj: 0.0629
# [u] size: 0.555, contain*: 0.762
# [f] mse: 0.0443, la_reg: 0.0691, norm_reg: 0.0000, obj: 0.0616
# [f] improve*: 0.184
#
# t: 4
# [h] n_eff: 24.37, w_sum: 24.94
# [u] loss: 0.0624, norm_reg: 0.0000, obj: 0.0624
# [u] size: 0.565, contain*: 0.762
# [f] mse: 0.0445, la_reg: 0.0679, norm_reg: 0.0000, obj: 0.0614
# [f] improve*: 0.185
#
# t: 5
# [h] n_eff: 24.18, w_sum: 24.38
# [u] loss: 0.0620, norm_reg: 0.0000, obj: 0.0620
# [u] size: 0.571, contain*: 0.762
# [f] mse: 0.0444, la_reg: 0.0673, norm_reg: 0.0000, obj: 0.0613
# [f] improve*: 0.186
#
# t: 6
# [h] n_eff: 24.18, w_sum: 24.20
# [u] loss: 0.0619, norm_reg: 0.0000, obj: 0.0619
# [u] size: 0.572, contain*: 0.762
# [f] mse: 0.0445, la_reg: 0.0668, norm_reg: 0.0000, obj: 0.0612
# [f] improve*: 0.186
#
# t: 7
# [h] n_eff: 24.14, w_sum: 24.01
# [u] loss: 0.0618, norm_reg: 0.0000, obj: 0.0618
# [u] size: 0.574, contain*: 0.762
# [f] mse: 0.0445, la_reg: 0.0664, norm_reg: 0.0000, obj: 0.0611
# [f] improve*: 0.186
#
# t: 8
# [h] n_eff: 24.10, w_sum: 23.84
# [u] loss: 0.0617, norm_reg: 0.0000, obj: 0.0617
# [u] size: 0.576, contain*: 0.762
# [f] mse: 0.0445, la_reg: 0.0661, norm_reg: 0.0000, obj: 0.0611
# [f] improve*: 0.186
#
# t: 9
# [h] n_eff: 24.07, w_sum: 23.70
# [u] loss: 0.0616, norm_reg: 0.0000, obj: 0.0616
# [u] size: 0.577, contain*: 0.762
# [f] mse: 0.0446, la_reg: 0.0658, norm_reg: 0.0000, obj: 0.0610
# [f] improve*: 0.186
#
# t: 10
# [h] n_eff: 24.05, w_sum: 23.59
# [u] loss: 0.0615, norm_reg: 0.0000, obj: 0.0615
# [u] size: 0.579, contain*: 0.762
# [f] mse: 0.0446, la_reg: 0.0657, norm_reg: 0.0000, obj: 0.0610
# [f] improve*: 0.187
#
# -- lam_: 0.5 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0453, la_reg: 0.0639, norm_reg: 0.0000, obj: 0.0773
# [f] improve*: 0.188
#
# t: 2
# [h] n_eff: 23.96, w_sum: 24.67
# [u] loss: 0.0629, norm_reg: 0.0000, obj: 0.0629
# [u] size: 0.582, contain*: 0.762
# [f] mse: 0.0465, la_reg: 0.0655, norm_reg: 0.0000, obj: 0.0792
# [f] improve*: 0.197
#
# t: 3
# [h] n_eff: 23.08, w_sum: 22.12
# [u] loss: 0.0620, norm_reg: 0.0000, obj: 0.0620
# [u] size: 0.621, contain*: 0.762
# [f] mse: 0.0468, la_reg: 0.0647, norm_reg: 0.0000, obj: 0.0792
# [f] improve*: 0.200
#
# t: 4
# [h] n_eff: 22.89, w_sum: 21.01
# [u] loss: 0.0616, norm_reg: 0.0000, obj: 0.0616
# [u] size: 0.638, contain*: 0.738
# [f] mse: 0.0471, la_reg: 0.0630, norm_reg: 0.0000, obj: 0.0786
# [f] improve*: 0.202
#
# t: 5
# [h] n_eff: 22.78, w_sum: 20.20
# [u] loss: 0.0614, norm_reg: 0.0000, obj: 0.0614
# [u] size: 0.651, contain*: 0.738
# [f] mse: 0.0474, la_reg: 0.0618, norm_reg: 0.0000, obj: 0.0783
# [f] improve*: 0.203
#
# t: 6
# [h] n_eff: 22.73, w_sum: 19.63
# [u] loss: 0.0613, norm_reg: 0.0000, obj: 0.0613
# [u] size: 0.661, contain*: 0.738
# [f] mse: 0.0476, la_reg: 0.0610, norm_reg: 0.0000, obj: 0.0781
# [f] improve*: 0.204
#
# t: 7
# [h] n_eff: 22.70, w_sum: 19.21
# [u] loss: 0.0612, norm_reg: 0.0000, obj: 0.0612
# [u] size: 0.669, contain*: 0.738
# [f] mse: 0.0477, la_reg: 0.0604, norm_reg: 0.0000, obj: 0.0779
# [f] improve*: 0.205
#
# t: 8
# [h] n_eff: 22.68, w_sum: 18.92
# [u] loss: 0.0612, norm_reg: 0.0000, obj: 0.0612
# [u] size: 0.674, contain*: 0.738
# [f] mse: 0.0479, la_reg: 0.0600, norm_reg: 0.0000, obj: 0.0778
# [f] improve*: 0.205
#
# t: 9
# [h] n_eff: 22.67, w_sum: 18.71
# [u] loss: 0.0611, norm_reg: 0.0000, obj: 0.0611
# [u] size: 0.678, contain*: 0.738
# [f] mse: 0.0479, la_reg: 0.0597, norm_reg: 0.0000, obj: 0.0778
# [f] improve*: 0.206
#
# t: 10
# [h] n_eff: 22.67, w_sum: 18.56
# [u] loss: 0.0611, norm_reg: 0.0000, obj: 0.0611
# [u] size: 0.681, contain*: 0.738
# [f] mse: 0.0480, la_reg: 0.0595, norm_reg: 0.0000, obj: 0.0777
# [f] improve*: 0.206
#
# -- lam_: 1.0 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0502, la_reg: 0.0532, norm_reg: 0.0000, obj: 0.1034
# [f] improve*: 0.210
#
# t: 2
# [h] n_eff: 21.98, w_sum: 19.97
# [u] loss: 0.0630, norm_reg: 0.0000, obj: 0.0630
# [u] size: 0.686, contain*: 0.762
# [f] mse: 0.0533, la_reg: 0.0624, norm_reg: 0.0000, obj: 0.1158
# [f] improve*: 0.220
#
# t: 3
# [h] n_eff: 21.65, w_sum: 17.46
# [u] loss: 0.0633, norm_reg: 0.0000, obj: 0.0633
# [u] size: 0.760, contain*: 0.738
# [f] mse: 0.0545, la_reg: 0.0618, norm_reg: 0.0000, obj: 0.1162
# [f] improve*: 0.224
#
# t: 4
# [h] n_eff: 21.60, w_sum: 16.14
# [u] loss: 0.0633, norm_reg: 0.0000, obj: 0.0633
# [u] size: 0.796, contain*: 0.738
# [f] mse: 0.0552, la_reg: 0.0598, norm_reg: 0.0000, obj: 0.1150
# [f] improve*: 0.228
#
# t: 5
# [h] n_eff: 21.65, w_sum: 15.30
# [u] loss: 0.0634, norm_reg: 0.0000, obj: 0.0634
# [u] size: 0.820, contain*: 0.738
# [f] mse: 0.0556, la_reg: 0.0589, norm_reg: 0.0000, obj: 0.1146
# [f] improve*: 0.230
#
# t: 6
# [h] n_eff: 21.70, w_sum: 14.77
# [u] loss: 0.0635, norm_reg: 0.0000, obj: 0.0635
# [u] size: 0.836, contain*: 0.738
# [f] mse: 0.0560, la_reg: 0.0584, norm_reg: 0.0000, obj: 0.1143
# [f] improve*: 0.231
#
# t: 7
# [h] n_eff: 21.74, w_sum: 14.44
# [u] loss: 0.0636, norm_reg: 0.0000, obj: 0.0636
# [u] size: 0.846, contain*: 0.762
# [f] mse: 0.0562, la_reg: 0.0580, norm_reg: 0.0000, obj: 0.1142
# [f] improve*: 0.232
#
# t: 8
# [h] n_eff: 21.76, w_sum: 14.24
# [u] loss: 0.0637, norm_reg: 0.0000, obj: 0.0637
# [u] size: 0.852, contain*: 0.762
# [f] mse: 0.0563, la_reg: 0.0579, norm_reg: 0.0000, obj: 0.1142
# [f] improve*: 0.232
#
# t: 9
# [h] n_eff: 21.78, w_sum: 14.12
# [u] loss: 0.0638, norm_reg: 0.0000, obj: 0.0638
# [u] size: 0.856, contain*: 0.762
# [f] mse: 0.0564, la_reg: 0.0577, norm_reg: 0.0000, obj: 0.1141
# [f] improve*: 0.232
#
# t: 10
# [h] n_eff: 21.79, w_sum: 14.04
# [u] loss: 0.0638, norm_reg: 0.0000, obj: 0.0638
# [u] size: 0.859, contain*: 0.762
# [f] mse: 0.0564, la_reg: 0.0577, norm_reg: 0.0000, obj: 0.1141
# [f] improve*: 0.233
#
# -- lam_: 2.0 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0663, norm_reg: 0.0000, obj: 0.0663
# [u] size: 0.488, contain*: 0.786
# [f] mse: 0.0626, la_reg: 0.0410, norm_reg: 0.0000, obj: 0.1447
# [f] improve*: 0.243
#
# t: 2
# [h] n_eff: 20.63, w_sum: 14.75
# [u] loss: 0.0670, norm_reg: 0.0000, obj: 0.0670
# [u] size: 0.881, contain*: 0.833
# [f] mse: 0.0739, la_reg: 0.0631, norm_reg: 0.0000, obj: 0.2000
# [f] improve*: 0.251
#
# t: 3
# [h] n_eff: 20.59, w_sum: 13.34
# [u] loss: 0.0716, norm_reg: 0.0000, obj: 0.0716
# [u] size: 1.041, contain*: 0.833
# [f] mse: 0.0781, la_reg: 0.0695, norm_reg: 0.0000, obj: 0.2171
# [f] improve*: 0.253
#
# t: 4
# [h] n_eff: 20.46, w_sum: 13.26
# [u] loss: 0.0734, norm_reg: 0.0000, obj: 0.0734
# [u] size: 1.075, contain*: 0.833
# [f] mse: 0.0786, la_reg: 0.0737, norm_reg: 0.0000, obj: 0.2259
# [f] improve*: 0.253
#
# t: 5
# [h] n_eff: 20.37, w_sum: 13.39
# [u] loss: 0.0735, norm_reg: 0.0000, obj: 0.0735
# [u] size: 1.069, contain*: 0.833
# [f] mse: 0.0789, la_reg: 0.0735, norm_reg: 0.0000, obj: 0.2259
# [f] improve*: 0.253
#
# t: 6
# [h] n_eff: 20.33, w_sum: 13.33
# [u] loss: 0.0736, norm_reg: 0.0000, obj: 0.0736
# [u] size: 1.071, contain*: 0.833
# [f] mse: 0.0790, la_reg: 0.0736, norm_reg: 0.0000, obj: 0.2262
# [f] improve*: 0.253
#
# t: 7
# [h] n_eff: 20.32, w_sum: 13.31
# [u] loss: 0.0736, norm_reg: 0.0000, obj: 0.0736
# [u] size: 1.072, contain*: 0.833
# [f] mse: 0.0791, la_reg: 0.0736, norm_reg: 0.0000, obj: 0.2262
# [f] improve*: 0.253
#
# t: 8
# [h] n_eff: 20.32, w_sum: 13.29
# [u] loss: 0.0737, norm_reg: 0.0000, obj: 0.0737
# [u] size: 1.073, contain*: 0.833
# [f] mse: 0.0791, la_reg: 0.0736, norm_reg: 0.0000, obj: 0.2263
# [f] improve*: 0.253
#
# t: 9
# [h] n_eff: 20.32, w_sum: 13.29
# [u] loss: 0.0737, norm_reg: 0.0000, obj: 0.0737
# [u] size: 1.073, contain*: 0.833
# [f] mse: 0.0791, la_reg: 0.0736, norm_reg: 0.0000, obj: 0.2263
# [f] improve*: 0.253
#
# t: 10
# [h] n_eff: 20.32, w_sum: 13.29
# [u] loss: 0.0737, norm_reg: 0.0000, obj: 0.0737
# [u] size: 1.073, contain*: 0.833
# [f] mse: 0.0791, la_reg: 0.0736, norm_reg: 0.0000, obj: 0.2263
# [f] improve*: 0.253

# %% [markdown]
# ## Evaluating the performance of the trained lookahead models

# %%
# evaluate

perf_la = {'mse':[], 'mae':[], 'improve':[], 'imprate':[], 'contain':[], 'size':[]}
for lam, model in zip(lams,models):
    perf_la['mse'].append([model.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_la['mae'].append([model.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_la['improve'].append([model.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])
    perf_la['imprate'].append([model.improve_rate(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])

    xsp = [model.move_points(x_) for x_ in xs]
    perf_la['contain'].append([model.contain(x_)[0] for x_ in [*xsp, x]])
    perf_la['size'].append([model.contain(x_)[1] for x_ in [*xsp, x]])
perf_la = {k:np.asarray(v) for k,v in zip(perf_la.keys(),perf_la.values())}

print('lookahead: eta:', eta)
for i in range(len(lams)):
    print('\n==============================================\n')
    print('lam:', lams[i])
    print('\ttrn\tts\tactv\tall\tf*')
    print(('mse'+'\t{:.4f}'*5).format(*perf_la['mse'][i,:], mse_star))
    print(('mae'+'\t{:.4f}'*5).format(*perf_la['mae'][i,:], mae_star))
    print(('imprv'+'\t{:.4f}'*4).format(*perf_la['improve'][i,:]))
    print(('imprt'+'\t{:.4f}'*4).format(*perf_la['imprate'][i,:]))
    print()
    print('\ttrn\'\ttst\'\tactv\'\tall\'\tall')
    print(('contn'+'\t{:.3f}'*5).format(*perf_la['contain'][i,:]))
    print(('intrsz'+'\t{:.3f}'*5).format(*perf_la['size'][i,:]))
# Out:
# lookahead: eta: 0.5
#
# ==============================================
#
# lam: 1e-05
# 	trn	ts	actv	all	f*
# mse	0.0431	0.0641	0.0486	0.1208	0.0411
# mae	0.1677	0.1897	0.1735	0.2618	0.1627
# imprv	0.1623	0.0751	0.1393	0.1714
# imprt	0.7857	0.8667	0.8070	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.762	0.600	0.719	0.837	0.803
# intrsz	0.489	0.512	0.495	1.036	1.003
#
# ==============================================
#
# lam: 0.0625
# 	trn	ts	actv	all	f*
# mse	0.0432	0.0695	0.0501	0.1188	0.0411
# mae	0.1678	0.1981	0.1758	0.2509	0.1627
# imprv	0.1703	0.0813	0.1469	0.1832
# imprt	0.8095	0.8667	0.8246	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.762	0.600	0.719	0.826	0.826
# intrsz	0.514	0.528	0.517	1.089	1.034
#
# ==============================================
#
# lam: 0.125
# 	trn	ts	actv	all	f*
# mse	0.0436	0.0746	0.0518	0.1210	0.0411
# mae	0.1687	0.2062	0.1786	0.2471	0.1627
# imprv	0.1772	0.0870	0.1535	0.1934
# imprt	0.8333	0.8667	0.8421	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.762	0.600	0.719	0.831	0.848
# intrsz	0.539	0.547	0.541	1.143	1.066
#
# ==============================================
#
# lam: 0.25
# 	trn	ts	actv	all	f*
# mse	0.0446	0.0822	0.0545	0.1317	0.0411
# mae	0.1707	0.2189	0.1834	0.2526	0.1627
# imprv	0.1866	0.0944	0.1623	0.2070
# imprt	0.8333	0.8667	0.8421	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.762	0.667	0.737	0.848	0.854
# intrsz	0.580	0.579	0.580	1.222	1.112
#
# ==============================================
#
# lam: 0.5
# 	trn	ts	actv	all	f*
# mse	0.0480	0.1016	0.0621	0.1784	0.0411
# mae	0.1773	0.2482	0.1959	0.2966	0.1627
# imprv	0.2060	0.1101	0.1807	0.2350
# imprt	0.8571	0.8667	0.8596	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.738	0.733	0.737	0.848	0.854
# intrsz	0.683	0.670	0.679	1.402	1.214
#
# ==============================================
#
# lam: 1.0
# 	trn	ts	actv	all	f*
# mse	0.0564	0.1436	0.0794	0.2644	0.0411
# mae	0.1956	0.3052	0.2244	0.3729	0.1627
# imprv	0.2326	0.1315	0.2060	0.2728
# imprt	0.8571	0.8667	0.8596	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.762	0.733	0.754	0.882	0.876
# intrsz	0.860	0.831	0.853	1.692	1.392
#
# ==============================================
#
# lam: 2.0
# 	trn	ts	actv	all	f*
# mse	0.0791	0.2727	0.1300	0.3266	0.0411
# mae	0.2380	0.4285	0.2881	0.4027	0.1627
# imprv	0.2535	0.1477	0.2256	0.3010
# imprt	0.8810	0.8667	0.8772	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	0.833	0.800	0.825	0.910	0.910
# intrsz	1.073	1.024	1.060	2.126	1.767

# %% [markdown]
# ## Training our CQR + lookahead model

# %%
# train our model
verbose = True

cqr_models = []
cqr_mfs = []
cqr_mus = []
for lam_ in lams:
    print('-- lam_:', lam_, '--')
    f = pred.PredModel(d, reg_type='none', alpha=0., lr=lr_f, num_iter=num_iter_f, num_iter_init=num_iter_init)
    u = CQR(d, tau=(0.05, 0.95), lr=0.001, num_iter=num_iter_g, train_calib_split=0.5)
    h = prop.PropModel(random_state=seed)

    model = Lookahead(f, u, h, lam=lam_, eta=eta, mask=mask, ground_truth_model=fstar)
    mf, mu = model.train(x_trn, y_trn, num_cycles=num_cycles, random_state=seed, verbose=verbose)

    cqr_models.append(model)
    cqr_mfs.append(mf)
    cqr_mus.append(mu)

cqr_mus = np.asarray(cqr_mus)
cqr_mfs = np.asarray(cqr_mfs)
# Out:
# -- lam_: 1e-05 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0048, norm_reg: 0.0000, obj: 0.0048
# [u] size: 0.927, contain*: 0.976
# [f] mse: 0.0431, la_reg: 0.5113, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 2
# [h] n_eff: 28.44, w_sum: 31.47
# [u] loss: 0.0169, norm_reg: 0.0000, obj: 0.0169
# [u] size: 0.795, contain*: 0.857
# [f] mse: 0.0431, la_reg: 0.4498, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 3
# [h] n_eff: 28.35, w_sum: 31.40
# [u] loss: 0.0147, norm_reg: 0.0000, obj: 0.0147
# [u] size: 1.959, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9636, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 4
# [h] n_eff: 28.27, w_sum: 31.34
# [u] loss: 0.0081, norm_reg: 0.0000, obj: 0.0081
# [u] size: 1.385, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.6987, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 5
# [h] n_eff: 28.21, w_sum: 31.28
# [u] loss: 0.0067, norm_reg: 0.0000, obj: 0.0067
# [u] size: 2.161, contain*: 1.000
# [f] mse: 0.0431, la_reg: 1.0367, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 6
# [h] n_eff: 28.15, w_sum: 31.23
# [u] loss: 0.0136, norm_reg: 0.0000, obj: 0.0136
# [u] size: 1.981, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9430, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 7
# [h] n_eff: 28.11, w_sum: 31.19
# [u] loss: 0.0080, norm_reg: 0.0000, obj: 0.0080
# [u] size: 2.146, contain*: 1.000
# [f] mse: 0.0431, la_reg: 1.0104, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 8
# [h] n_eff: 28.07, w_sum: 31.16
# [u] loss: 0.0169, norm_reg: 0.0000, obj: 0.0169
# [u] size: 2.116, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9903, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 9
# [h] n_eff: 28.04, w_sum: 31.13
# [u] loss: 0.0184, norm_reg: 0.0000, obj: 0.0184
# [u] size: 1.923, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9045, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# t: 10
# [h] n_eff: 28.02, w_sum: 31.10
# [u] loss: 0.0136, norm_reg: 0.0000, obj: 0.0136
# [u] size: 2.044, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9637, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.162
#
# -- lam_: 0.0625 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0167, norm_reg: 0.0000, obj: 0.0167
# [u] size: 2.336, contain*: 1.000
# [f] mse: 0.0431, la_reg: 1.1363, norm_reg: 0.0000, obj: 0.1141
# [f] improve*: 0.162
#
# t: 2
# [h] n_eff: 28.28, w_sum: 31.18
# [u] loss: 0.0098, norm_reg: 0.0000, obj: 0.0098
# [u] size: 1.357, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.7192, norm_reg: 0.0000, obj: 0.0881
# [f] improve*: 0.163
#
# t: 3
# [h] n_eff: 28.10, w_sum: 31.03
# [u] loss: 0.0090, norm_reg: 0.0000, obj: 0.0090
# [u] size: 1.318, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.6886, norm_reg: 0.0000, obj: 0.0861
# [f] improve*: 0.164
#
# t: 4
# [h] n_eff: 27.93, w_sum: 30.84
# [u] loss: 0.0073, norm_reg: 0.0000, obj: 0.0073
# [u] size: 1.452, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.7350, norm_reg: 0.0000, obj: 0.0891
# [f] improve*: 0.164
#
# t: 5
# [h] n_eff: 27.78, w_sum: 30.65
# [u] loss: 0.0070, norm_reg: 0.0000, obj: 0.0070
# [u] size: 1.687, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.8277, norm_reg: 0.0000, obj: 0.0949
# [f] improve*: 0.165
#
# t: 6
# [h] n_eff: 27.66, w_sum: 30.49
# [u] loss: 0.0017, norm_reg: 0.0000, obj: 0.0017
# [u] size: 1.898, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9192, norm_reg: 0.0000, obj: 0.1006
# [f] improve*: 0.165
#
# t: 7
# [h] n_eff: 27.58, w_sum: 30.34
# [u] loss: 0.0239, norm_reg: 0.0000, obj: 0.0239
# [u] size: 2.042, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.9586, norm_reg: 0.0000, obj: 0.1031
# [f] improve*: 0.166
#
# t: 8
# [h] n_eff: 27.52, w_sum: 30.22
# [u] loss: 0.0070, norm_reg: 0.0000, obj: 0.0070
# [u] size: 1.671, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.8097, norm_reg: 0.0000, obj: 0.0938
# [f] improve*: 0.166
#
# t: 9
# [h] n_eff: 27.47, w_sum: 30.16
# [u] loss: 0.0172, norm_reg: 0.0000, obj: 0.0172
# [u] size: 1.806, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.8744, norm_reg: 0.0000, obj: 0.0978
# [f] improve*: 0.166
#
# t: 10
# [h] n_eff: 27.42, w_sum: 30.08
# [u] loss: 0.0081, norm_reg: 0.0000, obj: 0.0081
# [u] size: 2.047, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.9729, norm_reg: 0.0000, obj: 0.1040
# [f] improve*: 0.166
#
# -- lam_: 0.125 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0046, norm_reg: 0.0000, obj: 0.0046
# [u] size: 2.513, contain*: 0.976
# [f] mse: 0.0431, la_reg: 1.2489, norm_reg: 0.0000, obj: 0.1992
# [f] improve*: 0.163
#
# t: 2
# [h] n_eff: 28.22, w_sum: 31.04
# [u] loss: 0.0105, norm_reg: 0.0000, obj: 0.0105
# [u] size: 1.782, contain*: 1.000
# [f] mse: 0.0431, la_reg: 0.9026, norm_reg: 0.0000, obj: 0.1560
# [f] improve*: 0.164
#
# t: 3
# [h] n_eff: 27.94, w_sum: 30.67
# [u] loss: 0.0096, norm_reg: 0.0000, obj: 0.0096
# [u] size: 0.776, contain*: 0.881
# [f] mse: 0.0431, la_reg: 0.4445, norm_reg: 0.0000, obj: 0.0987
# [f] improve*: 0.165
#
# t: 4
# [h] n_eff: 27.74, w_sum: 30.43
# [u] loss: 0.0072, norm_reg: 0.0000, obj: 0.0072
# [u] size: 1.482, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.7524, norm_reg: 0.0000, obj: 0.1372
# [f] improve*: 0.166
#
# t: 5
# [h] n_eff: 27.48, w_sum: 30.04
# [u] loss: 0.0117, norm_reg: 0.0000, obj: 0.0117
# [u] size: 0.968, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.5236, norm_reg: 0.0000, obj: 0.1087
# [f] improve*: 0.167
#
# t: 6
# [h] n_eff: 27.32, w_sum: 29.76
# [u] loss: 0.0188, norm_reg: 0.0000, obj: 0.0188
# [u] size: 0.935, contain*: 0.976
# [f] mse: 0.0433, la_reg: 0.5075, norm_reg: 0.0000, obj: 0.1067
# [f] improve*: 0.168
#
# t: 7
# [h] n_eff: 27.16, w_sum: 29.55
# [u] loss: 0.0123, norm_reg: 0.0000, obj: 0.0123
# [u] size: 1.227, contain*: 1.000
# [f] mse: 0.0433, la_reg: 0.6240, norm_reg: 0.0000, obj: 0.1213
# [f] improve*: 0.169
#
# t: 8
# [h] n_eff: 27.02, w_sum: 29.33
# [u] loss: 0.0100, norm_reg: 0.0000, obj: 0.0100
# [u] size: 1.792, contain*: 1.000
# [f] mse: 0.0434, la_reg: 0.8564, norm_reg: 0.0000, obj: 0.1504
# [f] improve*: 0.170
#
# t: 9
# [h] n_eff: 26.88, w_sum: 29.07
# [u] loss: 0.0091, norm_reg: 0.0000, obj: 0.0091
# [u] size: 1.879, contain*: 1.000
# [f] mse: 0.0435, la_reg: 0.8990, norm_reg: 0.0000, obj: 0.1558
# [f] improve*: 0.170
#
# t: 10
# [h] n_eff: 26.76, w_sum: 28.86
# [u] loss: 0.0021, norm_reg: 0.0000, obj: 0.0021
# [u] size: 1.939, contain*: 1.000
# [f] mse: 0.0435, la_reg: 0.9126, norm_reg: 0.0000, obj: 0.1576
# [f] improve*: 0.171
#
# -- lam_: 0.25 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0133, norm_reg: 0.0000, obj: 0.0133
# [u] size: 1.456, contain*: 1.000
# [f] mse: 0.0432, la_reg: 0.7380, norm_reg: 0.0000, obj: 0.2277
# [f] improve*: 0.164
#
# t: 2
# [h] n_eff: 27.75, w_sum: 30.90
# [u] loss: 0.0024, norm_reg: 0.0000, obj: 0.0024
# [u] size: 1.681, contain*: 1.000
# [f] mse: 0.0433, la_reg: 0.8410, norm_reg: 0.0000, obj: 0.2536
# [f] improve*: 0.166
#
# t: 3
# [h] n_eff: 27.27, w_sum: 30.30
# [u] loss: 0.0083, norm_reg: 0.0000, obj: 0.0083
# [u] size: 1.526, contain*: 1.000
# [f] mse: 0.0435, la_reg: 0.7536, norm_reg: 0.0000, obj: 0.2319
# [f] improve*: 0.169
#
# t: 4
# [h] n_eff: 26.68, w_sum: 29.40
# [u] loss: 0.0025, norm_reg: 0.0000, obj: 0.0025
# [u] size: 1.828, contain*: 1.000
# [f] mse: 0.0439, la_reg: 0.8788, norm_reg: 0.0000, obj: 0.2636
# [f] improve*: 0.173
#
# t: 5
# [h] n_eff: 26.03, w_sum: 28.42
# [u] loss: 0.0102, norm_reg: 0.0000, obj: 0.0102
# [u] size: 1.915, contain*: 1.000
# [f] mse: 0.0443, la_reg: 0.9044, norm_reg: 0.0000, obj: 0.2704
# [f] improve*: 0.176
#
# t: 6
# [h] n_eff: 25.50, w_sum: 27.41
# [u] loss: 0.0107, norm_reg: 0.0000, obj: 0.0107
# [u] size: 1.989, contain*: 1.000
# [f] mse: 0.0447, la_reg: 0.9245, norm_reg: 0.0000, obj: 0.2758
# [f] improve*: 0.180
#
# t: 7
# [h] n_eff: 25.04, w_sum: 26.59
# [u] loss: 0.0021, norm_reg: 0.0000, obj: 0.0021
# [u] size: 2.096, contain*: 1.000
# [f] mse: 0.0451, la_reg: 0.9708, norm_reg: 0.0000, obj: 0.2878
# [f] improve*: 0.182
#
# t: 8
# [h] n_eff: 24.77, w_sum: 25.80
# [u] loss: 0.0087, norm_reg: 0.0000, obj: 0.0087
# [u] size: 1.806, contain*: 1.000
# [f] mse: 0.0454, la_reg: 0.8250, norm_reg: 0.0000, obj: 0.2517
# [f] improve*: 0.185
#
# t: 9
# [h] n_eff: 24.52, w_sum: 25.23
# [u] loss: 0.0176, norm_reg: 0.0000, obj: 0.0176
# [u] size: 2.005, contain*: 1.000
# [f] mse: 0.0457, la_reg: 0.9037, norm_reg: 0.0000, obj: 0.2716
# [f] improve*: 0.186
#
# t: 10
# [h] n_eff: 24.40, w_sum: 24.78
# [u] loss: 0.0082, norm_reg: 0.0000, obj: 0.0082
# [u] size: 2.146, contain*: 1.000
# [f] mse: 0.0460, la_reg: 0.9531, norm_reg: 0.0000, obj: 0.2843
# [f] improve*: 0.188
#
# -- lam_: 0.5 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0053, norm_reg: 0.0000, obj: 0.0053
# [u] size: 2.057, contain*: 1.000
# [f] mse: 0.0435, la_reg: 1.0249, norm_reg: 0.0000, obj: 0.5559
# [f] improve*: 0.167
#
# t: 2
# [h] n_eff: 27.26, w_sum: 30.00
# [u] loss: 0.0134, norm_reg: 0.0000, obj: 0.0134
# [u] size: 2.218, contain*: 1.000
# [f] mse: 0.0441, la_reg: 1.0912, norm_reg: 0.0000, obj: 0.5897
# [f] improve*: 0.174
#
# t: 3
# [h] n_eff: 26.02, w_sum: 28.06
# [u] loss: 0.0133, norm_reg: 0.0000, obj: 0.0133
# [u] size: 2.217, contain*: 1.000
# [f] mse: 0.0449, la_reg: 1.0890, norm_reg: 0.0000, obj: 0.5895
# [f] improve*: 0.181
#
# t: 4
# [h] n_eff: 24.87, w_sum: 26.08
# [u] loss: 0.0187, norm_reg: 0.0000, obj: 0.0187
# [u] size: 1.945, contain*: 1.000
# [f] mse: 0.0466, la_reg: 0.9353, norm_reg: 0.0000, obj: 0.5142
# [f] improve*: 0.191
#
# t: 5
# [h] n_eff: 23.63, w_sum: 23.61
# [u] loss: 0.0140, norm_reg: 0.0000, obj: 0.0140
# [u] size: 2.042, contain*: 1.000
# [f] mse: 0.0479, la_reg: 0.9612, norm_reg: 0.0000, obj: 0.5285
# [f] improve*: 0.197
#
# t: 6
# [h] n_eff: 23.09, w_sum: 22.12
# [u] loss: 0.0120, norm_reg: 0.0000, obj: 0.0120
# [u] size: 1.999, contain*: 1.000
# [f] mse: 0.0503, la_reg: 0.9298, norm_reg: 0.0000, obj: 0.5152
# [f] improve*: 0.206
#
# t: 7
# [h] n_eff: 22.39, w_sum: 20.17
# [u] loss: 0.0138, norm_reg: 0.0000, obj: 0.0138
# [u] size: 2.188, contain*: 1.000
# [f] mse: 0.0528, la_reg: 1.0019, norm_reg: 0.0000, obj: 0.5538
# [f] improve*: 0.214
#
# t: 8
# [h] n_eff: 21.85, w_sum: 18.58
# [u] loss: 0.0072, norm_reg: 0.0000, obj: 0.0072
# [u] size: 2.285, contain*: 1.000
# [f] mse: 0.0550, la_reg: 1.0174, norm_reg: 0.0000, obj: 0.5637
# [f] improve*: 0.221
#
# t: 9
# [h] n_eff: 21.79, w_sum: 17.25
# [u] loss: 0.0020, norm_reg: 0.0000, obj: 0.0020
# [u] size: 2.064, contain*: 1.000
# [f] mse: 0.0553, la_reg: 0.9266, norm_reg: 0.0000, obj: 0.5186
# [f] improve*: 0.223
#
# t: 10
# [h] n_eff: 21.82, w_sum: 16.88
# [u] loss: 0.0223, norm_reg: 0.0000, obj: 0.0223
# [u] size: 1.964, contain*: 1.000
# [f] mse: 0.0580, la_reg: 0.8573, norm_reg: 0.0000, obj: 0.4866
# [f] improve*: 0.228
#
# -- lam_: 1.0 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0268, norm_reg: 0.0000, obj: 0.0268
# [u] size: 2.386, contain*: 1.000
# [f] mse: 0.0463, la_reg: 1.1685, norm_reg: 0.0000, obj: 1.2148
# [f] improve*: 0.171
#
# t: 2
# [h] n_eff: 26.47, w_sum: 29.17
# [u] loss: 0.0088, norm_reg: 0.0000, obj: 0.0088
# [u] size: 1.942, contain*: 1.000
# [f] mse: 0.0476, la_reg: 0.9396, norm_reg: 0.0000, obj: 0.9872
# [f] improve*: 0.182
#
# t: 3
# [h] n_eff: 24.74, w_sum: 26.16
# [u] loss: 0.0075, norm_reg: 0.0000, obj: 0.0075
# [u] size: 1.691, contain*: 0.976
# [f] mse: 0.0530, la_reg: 0.8174, norm_reg: 0.0000, obj: 0.8704
# [f] improve*: 0.199
#
# t: 4
# [h] n_eff: 22.31, w_sum: 22.31
# [u] loss: 0.0077, norm_reg: 0.0000, obj: 0.0077
# [u] size: 1.983, contain*: 1.000
# [f] mse: 0.0602, la_reg: 0.9082, norm_reg: 0.0000, obj: 0.9684
# [f] improve*: 0.213
#
# t: 5
# [h] n_eff: 21.19, w_sum: 19.24
# [u] loss: 0.0278, norm_reg: 0.0000, obj: 0.0278
# [u] size: 1.949, contain*: 1.000
# [f] mse: 0.0719, la_reg: 0.8575, norm_reg: 0.0000, obj: 0.9294
# [f] improve*: 0.232
#
# t: 6
# [h] n_eff: 20.41, w_sum: 15.63
# [u] loss: 0.0024, norm_reg: 0.0000, obj: 0.0024
# [u] size: 1.986, contain*: 1.000
# [f] mse: 0.0831, la_reg: 0.8351, norm_reg: 0.0000, obj: 0.9182
# [f] improve*: 0.243
#
# t: 7
# [h] n_eff: 20.86, w_sum: 13.30
# [u] loss: 0.0078, norm_reg: 0.0000, obj: 0.0078
# [u] size: 2.197, contain*: 1.000
# [f] mse: 0.0947, la_reg: 0.8839, norm_reg: 0.0000, obj: 0.9786
# [f] improve*: 0.256
#
# t: 8
# [h] n_eff: 21.15, w_sum: 11.32
# [u] loss: 0.0140, norm_reg: 0.0000, obj: 0.0140
# [u] size: 2.192, contain*: 1.000
# [f] mse: 0.1004, la_reg: 0.8677, norm_reg: 0.0000, obj: 0.9681
# [f] improve*: 0.266
#
# t: 9
# [h] n_eff: 21.87, w_sum: 9.90
# [u] loss: 0.0216, norm_reg: 0.0000, obj: 0.0216
# [u] size: 2.251, contain*: 1.000
# [f] mse: 0.1159, la_reg: 0.8627, norm_reg: 0.0000, obj: 0.9786
# [f] improve*: 0.280
#
# t: 10
# [h] n_eff: 22.45, w_sum: 8.38
# [u] loss: 0.0026, norm_reg: 0.0000, obj: 0.0026
# [u] size: 2.460, contain*: 1.000
# [f] mse: 0.1209, la_reg: 0.9447, norm_reg: 0.0000, obj: 1.0655
# [f] improve*: 0.285
#
# -- lam_: 2.0 --
# t: 0
# [f] mse: 0.0431, la_reg: 0.0000, norm_reg: 0.0000, obj: 0.0431
# [f] improve*: 0.161
#
# t: 1
# [h] n_eff: 28.56, w_sum: 31.54
# [u] loss: 0.0256, norm_reg: 0.0000, obj: 0.0256
# [u] size: 1.511, contain*: 0.976
# [f] mse: 0.0468, la_reg: 0.7673, norm_reg: 0.0000, obj: 1.5814
# [f] improve*: 0.169
#
# t: 2
# [h] n_eff: 25.84, w_sum: 30.42
# [u] loss: 0.0261, norm_reg: 0.0000, obj: 0.0261
# [u] size: 0.735, contain*: 0.833
# [f] mse: 0.0489, la_reg: 0.4393, norm_reg: 0.0000, obj: 0.9274
# [f] improve*: 0.175
#
# t: 3
# [h] n_eff: 25.62, w_sum: 28.53
# [u] loss: 0.0101, norm_reg: 0.0000, obj: 0.0101
# [u] size: 0.925, contain*: 0.952
# [f] mse: 0.0545, la_reg: 0.5085, norm_reg: 0.0000, obj: 1.0716
# [f] improve*: 0.184
#
# t: 4
# [h] n_eff: 24.56, w_sum: 25.43
# [u] loss: 0.0251, norm_reg: 0.0000, obj: 0.0251
# [u] size: 1.541, contain*: 1.000
# [f] mse: 0.0665, la_reg: 0.7527, norm_reg: 0.0000, obj: 1.5720
# [f] improve*: 0.199
#
# t: 5
# [h] n_eff: 24.71, w_sum: 20.11
# [u] loss: 0.0215, norm_reg: 0.0000, obj: 0.0215
# [u] size: 0.761, contain*: 0.857
# [f] mse: 0.0762, la_reg: 0.4043, norm_reg: 0.0000, obj: 0.8847
# [f] improve*: 0.212
#
# t: 6
# [h] n_eff: 25.00, w_sum: 15.21
# [u] loss: 0.0158, norm_reg: 0.0000, obj: 0.0158
# [u] size: 0.616, contain*: 0.786
# [f] mse: 0.0893, la_reg: 0.3178, norm_reg: 0.0000, obj: 0.7249
# [f] improve*: 0.223
#
# t: 7
# [h] n_eff: 25.58, w_sum: 11.31
# [u] loss: 0.0211, norm_reg: 0.0000, obj: 0.0211
# [u] size: 0.851, contain*: 0.976
# [f] mse: 0.1202, la_reg: 0.3656, norm_reg: 0.0000, obj: 0.8514
# [f] improve*: 0.241
#
# t: 8
# [h] n_eff: 26.24, w_sum: 7.53
# [u] loss: 0.0059, norm_reg: 0.0000, obj: 0.0059
# [u] size: 0.688, contain*: 0.881
# [f] mse: 0.1128, la_reg: 0.2785, norm_reg: 0.0000, obj: 0.6698
# [f] improve*: 0.239
#
# t: 9
# [h] n_eff: 26.60, w_sum: 6.43
# [u] loss: 0.0201, norm_reg: 0.0000, obj: 0.0201
# [u] size: 1.128, contain*: 1.000
# [f] mse: 0.1789, la_reg: 0.4021, norm_reg: 0.0000, obj: 0.9830
# [f] improve*: 0.277
#
# t: 10
# [h] n_eff: 27.75, w_sum: 4.24
# [u] loss: 0.0059, norm_reg: 0.0000, obj: 0.0059
# [u] size: 1.721, contain*: 1.000
# [f] mse: 0.2442, la_reg: 0.5748, norm_reg: 0.0000, obj: 1.3938
# [f] improve*: 0.314

# %% [markdown]
# ## Evaluating the performance of the trained lookahead+CQR models

# %%
perf_la_cqr = {'mse':[], 'mae':[], 'improve':[], 'imprate':[], 'contain':[], 'size':[]}
for lam, model in zip(lams,cqr_models):
    perf_la_cqr['mse'].append([model.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_la_cqr['mae'].append([model.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_la_cqr['improve'].append([model.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])
    perf_la_cqr['imprate'].append([model.improve_rate(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])

    xsp = [model.move_points(x_) for x_ in xs]
    perf_la_cqr['contain'].append([model.contain(x_)[0] for x_ in [*xsp, x]])
    perf_la_cqr['size'].append([model.contain(x_)[1] for x_ in [*xsp, x]])

perf_la_cqr = {k:np.asarray(v) for k,v in zip(perf_la_cqr.keys(),perf_la_cqr.values())}

print('lookahead + CQR: eta:', eta)
for i in range(len(lams)):
    print('\n==============================================\n')
    print('lam:', lams[i])
    print('\ttrn\tts\tactv\tall\tf*')
    print(('mse'+'\t{:.4f}'*5).format(*perf_la_cqr['mse'][i,:], mse_star))
    print(('mae'+'\t{:.4f}'*5).format(*perf_la_cqr['mae'][i,:], mae_star))
    print(('imprv'+'\t{:.4f}'*4).format(*perf_la_cqr['improve'][i,:]))
    print(('imprt'+'\t{:.4f}'*4).format(*perf_la_cqr['imprate'][i,:]))
    print()
    print('\ttrn\'\ttst\'\tactv\'\tall\'\tall')
    print(('contn'+'\t{:.3f}'*5).format(*perf_la_cqr['contain'][i,:]))
    print(('intrsz'+'\t{:.3f}'*5).format(*perf_la_cqr['size'][i,:]))
# Out:
# lookahead + CQR: eta: 0.5
#
# ==============================================
#
# lam: 1e-05
# 	trn	ts	actv	all	f*
# mse	0.0431	0.0641	0.0486	0.1208	0.0411
# mae	0.1677	0.1897	0.1735	0.2618	0.1627
# imprv	0.1623	0.0751	0.1393	0.1714
# imprt	0.7857	0.8667	0.8070	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.966	0.978
# intrsz	2.043	2.036	2.039	2.245	2.182
#
# ==============================================
#
# lam: 0.0625
# 	trn	ts	actv	all	f*
# mse	0.0432	0.0636	0.0486	0.1526	0.0411
# mae	0.1669	0.1862	0.1720	0.2960	0.1627
# imprv	0.1665	0.0782	0.1432	0.1778
# imprt	0.8095	0.8667	0.8246	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.966	0.972
# intrsz	2.045	2.029	2.041	2.247	2.181
#
# ==============================================
#
# lam: 0.125
# 	trn	ts	actv	all	f*
# mse	0.0435	0.0645	0.0491	0.1798	0.0411
# mae	0.1668	0.1860	0.1718	0.3204	0.1627
# imprv	0.1710	0.0817	0.1475	0.1848
# imprt	0.8333	0.8667	0.8421	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.944	0.955
# intrsz	1.940	1.907	1.932	2.135	2.053
#
# ==============================================
#
# lam: 0.25
# 	trn	ts	actv	all	f*
# mse	0.0460	0.0715	0.0527	0.2835	0.0411
# mae	0.1699	0.2013	0.1781	0.4010	0.1627
# imprv	0.1877	0.0948	0.1632	0.2094
# imprt	0.8333	0.8667	0.8421	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.972	0.983
# intrsz	2.147	2.122	2.141	2.365	2.267
#
# ==============================================
#
# lam: 0.5
# 	trn	ts	actv	all	f*
# mse	0.0580	0.0962	0.0681	0.5180	0.0411
# mae	0.1945	0.2356	0.2053	0.5380	0.1627
# imprv	0.2284	0.1272	0.2017	0.2686
# imprt	0.8571	0.8667	0.8596	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.944	0.933
# intrsz	1.962	1.928	1.954	2.133	2.034
#
# ==============================================
#
# lam: 1.0
# 	trn	ts	actv	all	f*
# mse	0.1210	0.1877	0.1385	2.5287	0.0411
# mae	0.2922	0.3254	0.3010	1.2013	0.1627
# imprv	0.2845	0.1716	0.2548	0.3486
# imprt	0.9048	0.8667	0.8947	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.972	0.989
# intrsz	2.462	2.425	2.453	2.630	2.488
#
# ==============================================
#
# lam: 2.0
# 	trn	ts	actv	all	f*
# mse	0.2448	0.3163	0.2636	9.4299	0.0411
# mae	0.4098	0.4640	0.4241	2.2575	0.1627
# imprv	0.3140	0.1931	0.2822	0.3977
# imprt	0.9048	0.8667	0.8947	0.9944
#
# 	trn'	tst'	actv'	all'	all
# contn	1.000	1.000	1.000	0.961	0.933
# intrsz	1.754	1.694	1.735	1.933	1.731

# %% [markdown]
# ## Training the baseline model for different values of l2 - regularizer coefficient

# %%
# train baseline model on all alphas

verbose = False

models_base = []
for alpha in alphas:
    f_base = pred.PredModel(d, reg_type='l2', alpha=alpha, lr=lr_f, num_iter_init=num_iter_init)
    model_base = Lookahead(f_base, None, None, lam=0., eta=eta, mask=mask, ground_truth_model=fstar)
    _, _ = model_base.train(x_trn, y_trn, num_cycles=0, random_state=seed, verbose=verbose)
    models_base.append(model_base)

perf_base = {'mse':[], 'mae':[], 'improve':[], 'imprate':[]} #, 'contain':[], 'size':[]}
for model in models_base:
    perf_base['mse'].append([model.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_base['mae'].append([model.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_base['improve'].append([model.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])
    perf_base['imprate'].append([model.improve_rate(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])
perf_base = {k:np.asarray(v) for k,v in zip(perf_base.keys(),perf_base.values())}

# %% [markdown]
# ## Training naive model and evaluate on multiple step size scales

# %%
models_naive = []
scales = np.arange(1,1.16,0.01)
alpha_naive = 4.0

f_naive = pred.PredModel(d, reg_type='l2', alpha=alpha_naive, lr=lr_f, num_iter_init=num_iter_init)
model_naive = Lookahead(f_naive, None, None, lam=0., eta=eta, mask=mask, ground_truth_model=fstar)
_, _ = model_naive.train(x_trn, y_trn, num_cycles=0, random_state=seed, verbose=verbose)
w_ = model_naive.f.model.state_dict()['linear.weight'].detach().numpy()

perf_naive = {'mse':[], 'mae':[], 'improve':[], 'imprate':[]} #, 'contain':[], 'size':[]}
for scale in scales:
    dict_ = OrderedDict({'linear.weight':torch.Tensor(w_*scale)})
    model_naive.f.model.load_state_dict(dict_, strict=False)
    models_naive.append(model_naive)
    perf_naive['mse'].append([model_naive.mse(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_naive['mae'].append([model_naive.mae(x_,y_) for x_,y_ in zip(xs,ys)])
    perf_naive['improve'].append([model_naive.improve(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])
    perf_naive['imprate'].append([model_naive.improve_rate(x_,y_,eta,mask) for x_,y_ in zip(xs,ys)])

perf_naive = {k:np.asarray(v) for k,v in zip(perf_naive.keys(),perf_naive.values())}

# %% [markdown]
# ## Plotting the trade-off curve between mse and mean improvement for different settings

# %%
# plot
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

SAVE_FIG = False
fname = 'wine_nomask_v3_rmse'

print('seed:',seed,', eta:',eta)

plt.rcParams['figure.figsize'] = (6.0, 4.0)

plt.plot(perf_base['improve'][:,0], perf_base['mse'][:,0],'b-x')
plt.plot(perf_la['improve'][:,0], perf_la['mse'][:,0],'g-x')
plt.plot(perf_la_cqr['improve'][:,0], perf_la_cqr['mse'][:,0],'m-x')
plt.plot(perf_naive['improve'][:,0], perf_naive['mse'][:,0],'r-x')

plt.title('frontier - train')
plt.ylabel('mse')
plt.xlabel('improve')
plt.legend(['base (alpha)', 'la (lambda)', 'la+cqr (lambda)', 'naive (step size)'])
plt.grid()
plt.ylim([0.,0.18])
plt.xlim([0,0.3])
plt.show()

plt.plot(perf_base['improve'][:,1], np.sqrt(perf_base['mse'][:,1]),'-o',c='b')
plt.plot(perf_la['improve'][:,1], np.sqrt(perf_la['mse'][:,1]),'-o',markerfacecolor='white', c='g')
plt.plot(perf_la_cqr['improve'][:,1], np.sqrt(perf_la_cqr['mse'][:,1]),'-o',markerfacecolor='white', c='m')
plt.plot(perf_naive['improve'][:,1], np.sqrt(perf_naive['mse'][:,1]),'--',alpha=0.7, c='r')

plt.title('accuracy-improvement frontier (full mutability)')
plt.ylabel('RMSE [$(y-\hat{y})^2$]')
plt.xlabel('average improvement [$y\'-y$]')
plt.legend([
    r'baseline ($\lambda$=0, varying $\alpha$)',
    r'lookahead (varying $\lambda$, $\alpha$=0)',
    r'lookahead + cqr (varying $\lambda$, $\alpha$=0)',
    r'scaling ($\lambda$=0, optimal $\alpha$, varying $c$)',
],
    loc='upper left',
)
plt.grid()
plt.ylim([0.2,0.5])
plt.xlim([0,0.14])

xx = perf_base['improve'][0,1]
yy =np.sqrt(perf_base['mse'][0,1])
plt.annotate(r'$\alpha$',
ha = 'center', va = 'bottom',
xytext = (xx-0.006,yy+0.012),
xy = (xx-0.022, yy),
arrowprops = { 'facecolor' : 'black', 'shrink' : 0.05 , 'width':0.5, 'headwidth':7, 'headlength':7},
fontsize=11)
plt.annotate(r'$\lambda$',
ha = 'center', va = 'bottom',
xytext = (xx+0.008,yy+0.027),
xy = (xx+0.023, yy+0.08),
arrowprops = { 'facecolor' : 'black', 'shrink' : 0.05 , 'width':0.5, 'headwidth':7, 'headlength':7},
fontsize=11)
xx2 = perf_base['improve'][-4,1]
yy2 = np.sqrt(perf_base['mse'][-4,1])
plt.annotate(r'$c$',
ha = 'center', va = 'bottom',
xytext = (xx2,yy2+0.02),
xy = (xx2+0.005, yy2+0.06),
arrowprops = { 'facecolor' : 'black', 'shrink' : 0.05 , 'width':0.5, 'headwidth':7, 'headlength':7},
fontsize=11)


ax = plt.gca()
axins = inset_axes(ax, width="25%", height="25%", loc=4)
axins.plot(np.linspace(0,1,len(alphas)),perf_base['imprate'][:,1],'-o', c='b', markerfacecolor=None,markersize=3)
axins.plot(np.linspace(0,1,len(lams)),perf_la['imprate'][:,1],'-o', c='g', markerfacecolor='white',markersize=3)
axins.plot(np.linspace(0,1,len(lams)),perf_la_cqr['imprate'][:,1],'-o', c='m', markerfacecolor='white',markersize=3)
axins.set_xticks([])
axins.set_yticks([0.4,0.6, 1.0])
axins.yaxis.tick_right()
axins.set_xlim([0,1])
axins.set_ylabel('imp. rate')


if SAVE_FIG:
    plt.draw()
    plt.savefig(fname+'.eps', format='eps', bbox_inches='tight')
    plt.savefig(fname+'.png', format='png', dpi=300, bbox_inches='tight')
    print('saved ' + fname)
else:
    plt.show()
# Out:
# seed: 1 , eta: 0.5

# %% [markdown]
# ## Effect of varying the coefficient of look ahead regularizer

# %%
ws_la_cqr = np.asarray([m.f.model.linear.weight.detach().numpy().squeeze() for m in cqr_models])
ws_la = np.asarray([m.f.model.linear.weight.detach().numpy().squeeze() for m in models])
ws_base = np.asarray([m.f.model.linear.weight.detach().numpy().squeeze() for m in models_base])

plt.rcParams['figure.figsize'] = (6.0, 4.0)

plt.plot(np.arange(len(lams))+0.5,ws_la[:,:2],'x-', c='g')
plt.plot(np.arange(len(lams))+0.5,ws_la[:,2:],'-', c='g')

plt.plot(np.arange(len(lams))+0.5,ws_la_cqr[:,:2],'x-', c='m')
plt.plot(np.arange(len(lams))+0.5,ws_la_cqr[:,2:],'-', c='m')

plt.gca().set_prop_cycle(None)
for i in range(len(w_bench)):
    plt.plot(0,w_bench[i],'o')

plt.gca().set_prop_cycle(None)
plt.plot(np.arange(0,-len(alphas),-1)-0.5,ws_base,'-.')
plt.legend([str(i) for i in range(d)])
plt.grid()
plt.ylim([-0.4,0.4])
plt.show()
